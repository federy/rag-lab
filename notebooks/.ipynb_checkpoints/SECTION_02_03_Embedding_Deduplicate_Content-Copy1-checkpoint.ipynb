# %% [markdown]
# # Setup

# %% [markdown]
# ## Load API Keys

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Tracing

# %%
from langfuse.openai import AsyncOpenAI  # autoinstrmenttion

# %% [markdown]
# ## Setup OpenAI

# %%
client = AsyncOpenAI()

# %%
EMBED_MODEL = "text-embedding-3-large"

# %%
GPT4O_MINI = "o4-mini-2025-04-16"

# %% [markdown]
# ## LLM Call Helpers

# %%
def _msg(role, content):
    return {'role': role, 'content': content}

def system(content):
    return _msg('system', content)

def user(content):
    return _msg('user', content)

def assistant(content):
    return _msg('assistant', content)

# %% [markdown]
# ## Embedding Call Helpers

# %%
def get_embedding(e) -> list[float]:
    return e.data[0].embedding

# %% [markdown]
# ## Compute Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from openai.types.create_embedding_response import CreateEmbeddingResponse

# %%
def embedding_cosine_sim(e1: CreateEmbeddingResponse, e2: CreateEmbeddingResponse) -> float:
    e1, e2 = get_embedding(e1), get_embedding(e2)
    to_np = lambda e: np.array(e).reshape(1, -1)
    e1, e2 = to_np(e1), to_np(e2)
    _cos_sim = cosine_similarity(e1, e2)
    return _cos_sim[0][0]

# %% [markdown]
# ## Cache System

# %%
from diskcache import Cache

# %%
cache = Cache(directory=".cache_course")

# %%
import asyncio

# %%
async def set_async(key, val, **kwargs):
    return await asyncio.to_thread(cache.set, key, val, **kwargs)

async def get_async(key, default=None, **kwargs):
    return await asyncio.to_thread(cache.get, key, default, **kwargs)

# %%
import json
from hashlib import md5

def make_cache_key(key_name, **kwargs):
    kwargs_string = json.dumps(kwargs, sort_keys=True)
    kwargs_hash = md5(kwargs_string.encode('utf-8')).hexdigest()
    cache_key = f"{key_name}__{kwargs_hash}"
    return cache_key

# %% [markdown]
# ## [EMBEDDING] Cached and Retried Calls

# %%
from pydantic import BaseModel

def _make_key_for_cached_embedding_with_retry(
    *,
    model,
    input,
    **kwargs,
):
    return make_cache_key(
        "openai_parsed_chat",
        model=model,
        input=input,
        **kwargs
    )

# %%
from openai.types.create_embedding_response import CreateEmbeddingResponse
from functools import wraps
from openai import APITimeoutError, RateLimitError
from pydantic import BaseModel
import backoff


CACHE_MISS_SENTINEL = object()


@wraps(client.embeddings.create)
async def cached_embedding_with_retry(
    *,
    model,
    input,
    **kwargs,
) -> CreateEmbeddingResponse:
    # CREATE CACHE KEY
    cache_key = _make_key_for_cached_embedding_with_retry(
        model=model,
        input=input,
        **kwargs
    )

    cached_value = await get_async(cache_key, default=CACHE_MISS_SENTINEL)
    # CACHE MISS
    if cached_value is CACHE_MISS_SENTINEL:
        @backoff.on_exception(
            backoff.expo,
            (APITimeoutError, RateLimitError)
        )
        async def do_call():
            return await client.embeddings.create(
                model=model,
                input=input,
                **kwargs
            )
        embedding = await do_call()
        await set_async(cache_key, embedding.model_dump_json())
        return embedding
    # CACHE HIT
    else:
        embedding = CreateEmbeddingResponse.model_validate(json.loads(cached_value))
        return embedding

# %% [markdown]
# ## [LLM] Cached, Retried, and Traced Calls

# %%
from pydantic import BaseModel

def _make_key_for_cached_chat_completion_parsed_with_retry(
    *,
    model,
    messages,
    response_format: BaseModel,
    **kwargs,
):
    return make_cache_key(
        "openai_parsed_chat",
        model=model,
        messages=messages,
        response_format=response_format.model_json_schema(),
        **kwargs
    )

# %%
from openai.types.chat import ParsedChatCompletion
from functools import wraps
from openai import APITimeoutError, RateLimitError
from pydantic import BaseModel
from typing_extensions import TypeVar
import backoff

ResponseFormatT = TypeVar("ResponseFormatT", bound=BaseModel)

CACHE_MISS_SENTINEL = object()


@wraps(client.chat.completions.parse)
async def cached_chat_completion_parsed_with_retry(
    *,
    model,
    messages,
    response_format: ResponseFormatT,
    **kwargs,
) -> ParsedChatCompletion[ResponseFormatT]:
    # CREATE CACHE KEY
    cache_key = _make_key_for_cached_chat_completion_parsed_with_retry(
        model=model,
        messages=messages,
        response_format=response_format,
        **kwargs
    )

    cached_value = await get_async(cache_key, default=CACHE_MISS_SENTINEL)
    # CACHE MISS
    if cached_value is CACHE_MISS_SENTINEL:
        @backoff.on_exception(
            backoff.expo,
            (APITimeoutError, RateLimitError)
        )
        async def do_call():
            return await client.chat.completions.parse(
                model=model,
                messages=messages,
                response_format=response_format,
                **kwargs
            )
        completion = await do_call()
        await set_async(cache_key, completion.model_dump_json())
        return completion
    # CACHE HIT
    else:
        # TODO: Tracing Code (next section)
        # return 
        completion = ParsedChatCompletion.model_validate(json.loads(cached_value))
        for choice in completion.choices:
            if not choice.message.refusal:
                choice.message.parsed = response_format.model_validate(
                    choice.message.parsed
                )
        return completion

# %% [markdown]
# ## Sanity Checks

# %%
# sanity check
embedding = await cached_embedding_with_retry(
    input="input: 'Union[str, List[str], Iterable[int], Iterable[Iterable[int]]]'",
    model=EMBED_MODEL
)
embedding_cosine_sim(embedding, embedding)
# Out:
# np.float64(0.9999999999999978)

# %%
# sanity check
from pydantic import BaseModel

class CalendarEvent(BaseModel):
    name: str
    date: str
    participants: list[str]

completion = await cached_chat_completion_parsed_with_retry(
    model=GPT4O_MINI,
    messages=[
        {"role": "system", "content": "Extract the event information."},
        {"role": "user", "content": "Alice and Bob are going to a science fair on Friday."},
    ],
    response_format=CalendarEvent,
)

event = completion.choices[0].message.parsed
event
# Out:
# CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob'])

# %% [markdown]
# ---

# %% [markdown]
# # Synthetic Data Filtering

# %% [markdown]
# ## Get the embedding for each question

# %%
import pandas as pd
import ast

emails = pd.read_csv('paul_allen_sent_email_with_questions_v1.csv')
emails['questions'] = emails['questions'].apply(ast.literal_eval)

# %%
def _make_ds(id_message, id_question, question, embedding=None):
    return {
        "id_message": id_message,
        "id_question": id_question,
        "question": question,
        "embedding": embedding
    }

# %%
questions_with_embeddings = []
index_for_questions_with_embeddings = {}

# %%
for e_idx, email in emails.iterrows():
    index_for_questions_with_embeddings[e_idx] = {}
    for q_idx, question in enumerate(email.questions):
        _ds = _make_ds(
            e_idx, q_idx, question
        )
        index_for_questions_with_embeddings[e_idx][q_idx] = _ds
        questions_with_embeddings.append(_ds)

# %%
index_for_questions_with_embeddings[0]
# Out:
# {0: {'id_message': 0,
#   'id_question': 0,
#   'question': 'What is the bid amount for Sagewood?',
#   'embedding': None},
#  1: {'id_message': 0,
#   'id_question': 1,
#   'question': 'What rate is being requested for Sagewood?',
#   'embedding': None},
#  2: {'id_message': 0,
#   'id_question': 2,
#   'question': 'What is the term dependent on for the Sagewood bid?',
#   'embedding': None},
#  3: {'id_message': 0,
#   'id_question': 3,
#   'question': 'What is the maximum rate mentioned for the Sagewood bid?',
#   'embedding': None},
#  4: {'id_message': 0,
#   'id_question': 4,
#   'question': 'Who is the recipient of the email?',
#   'embedding': None},
#  5: {'id_message': 0,
#   'id_question': 5,
#   'question': 'What asset is being referenced in the bid?',
#   'embedding': None}}

# %%
import traceback

tasks = []

for ds in questions_with_embeddings:
    async def do_task(ds):
        try:
            ds['embedding'] = await cached_embedding_with_retry(
                input=ds['question'],
                model=EMBED_MODEL
            )
        except Exception as e:
            return (ds, e, traceback.format_exc())
            
    tasks.append(do_task(ds))

# %%
len(tasks)
# Out:
# 1153

# %%
from tqdm.asyncio import tqdm_asyncio

results = await tqdm_asyncio.gather(*tasks)
# Out:
# 100%|██████████| 1153/1153 [00:02<00:00, 479.82it/s]

# %%
len([r for r in results if r])
# Out:
# 0

# %% [markdown]
# # Creating a list of Bad Questions

# %%
from operator import itemgetter

def find_exact_duplicates():
    get_question = itemgetter('question')
    questions = map(get_question, questions_with_embeddings)
    seen_questions = {}
    exact_duplicates = []
    for q in questions:
        if q in seen_questions:
            exact_duplicates.append(q)
        else:
            seen_questions[q] = True
    return set(exact_duplicates)

exact_duplicates = find_exact_duplicates()

# %%
exact_duplicates
# Out:
# {"How much are the builders' bids for the house project?",
#  'What does Phillip refer to himself as in the email?',
#  "What is Phillip's name in the email?",
#  'What is the cell phone number to reach Phillip Allen?',
#  'What is the email address of Phillip Allen?',
#  'What is the fax number provided in the email?',
#  'What is the intended shape of the kitchen island?',
#  'What is the name of the person addressed in the email?',
#  'What is the overall dimension of the house mentioned in the email?',
#  'What is the purpose of the email?',
#  'What is the subject of the email?',
#  'What material does Paul Allen suggest for the exterior of the house?',
#  'What style of house is Paul Allen aiming for?',
#  'What time is the meeting scheduled for?',
#  'What type of roof does Paul Allen want for the house?',
#  'When will Phillip talk to Lucy again?',
#  'Who is the email addressed to?',
#  'Who is the recipient of the email?',
#  'Who is the sender of the email?',
#  'Who sent the email?'}

# %%
bad_questions = list(exact_duplicates)

# %%
bad_questions
# Out:
# ['Who sent the email?',
#  'What is the cell phone number to reach Phillip Allen?',
#  'What is the subject of the email?',
#  'What is the fax number provided in the email?',
#  'What time is the meeting scheduled for?',
#  'Who is the recipient of the email?',
#  'What style of house is Paul Allen aiming for?',
#  'What does Phillip refer to himself as in the email?',
#  "What is Phillip's name in the email?",
#  'When will Phillip talk to Lucy again?',
#  "How much are the builders' bids for the house project?",
#  'What type of roof does Paul Allen want for the house?',
#  'What is the overall dimension of the house mentioned in the email?',
#  'Who is the sender of the email?',
#  'What is the purpose of the email?',
#  'What is the intended shape of the kitchen island?',
#  'What material does Paul Allen suggest for the exterior of the house?',
#  'What is the email address of Phillip Allen?',
#  'What is the name of the person addressed in the email?',
#  'Who is the email addressed to?']

# %% [markdown]
# # Find questions generated from the same email that are roughly the same

# %%
from itertools import combinations

# %%
email_combinations = {}
email_combinations_similarity = {}

for e_id in index_for_questions_with_embeddings:
    email_combinations[e_id] = list(combinations(index_for_questions_with_embeddings[e_id], 2))
    email_combinations_similarity[e_id] = []
    for (q1, q2) in email_combinations[e_id]:
        e1 = index_for_questions_with_embeddings[e_id][q1]['embedding']
        e2 = index_for_questions_with_embeddings[e_id][q2]['embedding']
        email_combinations_similarity[e_id].append(
            embedding_cosine_sim(e1, e2)
        )

# %%
from pprint import pprint
likely_duplicates = []

for e_id in email_combinations_similarity:
    for (q1, q2), similarity_score in zip(email_combinations[e_id], email_combinations_similarity[e_id]):
        question1 = index_for_questions_with_embeddings[e_id][q1]['question']
        question2 = index_for_questions_with_embeddings[e_id][q2]['question']
        if similarity_score > 0.8 and question1 != question2:
            likely_duplicates.append((e_id, q1, q2))
            pprint((
                f"{similarity_score:.2f}",
                f"{(e_id, q1)=}, {(e_id, q2)}",
                question1,
                question2,
            ))
            print()
# Out:
# ('0.86',
#  '(e_id, q1)=(15, 1), (15, 2)',
#  'Who is the master user for ft-west after the change?',
#  'Who is the master user for im-west after the change?')
#
# ('0.83',
#  '(e_id, q1)=(20, 1), (20, 2)',
#  'Who approved granting executing ids?',
#  'To whom were the executing ids granted?')
#
# ('0.94',
#  '(e_id, q1)=(21, 0), (21, 3)',
#  'What time will the updated curves be sent?',
#  'What date will the updated curves be sent?')
#
# ('0.81',
#  '(e_id, q1)=(23, 1), (23, 3)',
#  'what is being discussed in terms of kim olinger?',
#  'which individual is mentioned in relation to kim olinger?')
#
# ('0.81',
#  '(e_id, q1)=(52, 1), (52, 2)',
#  'What time is the inspection set for?',
#  'What day is the inspection scheduled?')
#
# ('0.87',
#  '(e_id, q1)=(65, 1), (65, 4)',
#  'What does Phillip consider for owner financing?',
#  'What are the terms that Phillip is considering for owner financing?')
#
# ('0.80',
#  '(e_id, q1)=(66, 0), (66, 5)',
#  'What products are routed to nw basis?',
#  'Which products are mentioned in relation to nw basis?')
#
# ('0.80',
#  '(e_id, q1)=(70, 1), (70, 2)',
#  'What would the 6 month payout be per month?',
#  'What would the 12 month payout be per month?')
#
# ('0.85',
#  '(e_id, q1)=(94, 2), (94, 3)',
#  'What day is the meeting scheduled for?',
#  'What time is the meeting scheduled for?')
#
# ('0.81',
#  '(e_id, q1)=(130, 0), (130, 1)',
#  'What formula should be used in column e?',
#  'What should be the formula in column h?')
#
# ('0.94',
#  '(e_id, q1)=(135, 0), (135, 1)',
#  'What was the anticipated socal/san juan spread on July 1?',
#  'What was the actual socal/san juan spread on July 1?')
#
# ('0.88',
#  '(e_id, q1)=(135, 2), (135, 3)',
#  'What was the perceived index on August 1?',
#  'What was the actual index on August 1?')
#
# ('0.87',
#  '(e_id, q1)=(150, 0), (150, 3)',
#  'What is the price per duplex for the 22 units sold by Reagan Lehmann?',
#  'What is the price per duplex for the units that Reagan is selling?')
#
# ('0.81',
#  '(e_id, q1)=(151, 0), (151, 4)',
#  'What is the price Phillip is prepared to pay for sagewood?',
#  'Does Phillip indicate he is prepared to pay more than 2.7 for sagewood?')
#
# ('0.91',
#  '(e_id, q1)=(161, 1), (161, 4)',
#  "How much higher is Phillip Allen's bid per square foot compared to Reagan's "
#  'units under construction?',
#  'What is the price per square foot that Phillip Allen is bidding compared to '
#  'the units sold by Reagan?')
#
# ('0.90',
#  '(e_id, q1)=(163, 1), (163, 3)',
#  "What are the unhedged amounts for Denver's short Rockies position in 2003, "
#  '2004, and 2005?',
#  "How much is Denver's short Rockies position unhedged in 2003?")
#
# ('0.91',
#  '(e_id, q1)=(163, 1), (163, 4)',
#  "What are the unhedged amounts for Denver's short Rockies position in 2003, "
#  '2004, and 2005?',
#  "How much is Denver's short Rockies position unhedged in 2004 and 2005?")
#
# ('0.97',
#  '(e_id, q1)=(163, 3), (163, 4)',
#  "How much is Denver's short Rockies position unhedged in 2003?",
#  "How much is Denver's short Rockies position unhedged in 2004 and 2005?")
#
# ('0.85',
#  '(e_id, q1)=(181, 1), (181, 3)',
#  'Who is the sender of the email?',
#  "What is the sender's email address?")
#
# ('0.84',
#  '(e_id, q1)=(185, 2), (185, 3)',
#  'who is the sender of the email?',
#  "what is the sender's name as mentioned in the email?")
#
# ('0.84',
#  '(e_id, q1)=(192, 0), (192, 5)',
#  'What is the total amount to be recognized as transport expense by the west '
#  'desk?',
#  'How much will be reimbursed to the west desk for the transport expense?')
#
# ('0.81',
#  '(e_id, q1)=(200, 0), (200, 1)',
#  'What is the amount that #37 i.knockum has paid until?',
#  'When did #37 i.knockum make a payment of 250.00?')
#
# ('0.81',
#  '(e_id, q1)=(203, 3), (203, 4)',
#  'What does Phillip want to know about the investment dollars timeline?',
#  'What does Phillip want to get a feel for regarding the investment dollars?')
#
# ('0.86',
#  '(e_id, q1)=(208, 2), (208, 3)',
#  'Who did Paul Allen support for promotion?',
#  'Who did Paul Allen oppose for promotion?')
#
# ('0.83',
#  '(e_id, q1)=(209, 0), (209, 1)',
#  'What amount did Neil Moreno pay on 11/24?',
#  'Did Neil Moreno pay anything on 12/01?')
#
# ('0.88',
#  '(e_id, q1)=(220, 0), (220, 2)',
#  'What day and time did Phillip suggest for the meeting?',
#  'What specific time did Phillip propose for the meeting?')
#
# ('0.86',
#  '(e_id, q1)=(242, 0), (242, 4)',
#  "What is Phillip Allen's work phone number?",
#  'What is the cell phone number for Phillip Allen?')
#
# ('0.81',
#  '(e_id, q1)=(253, 0), (253, 5)',
#  'What should #28 have paid on 1/12?',
#  'How much did #28 pay on 1/19?')
#
# ('0.92',
#  '(e_id, q1)=(277, 2), (277, 3)',
#  'Which tenant missed rent on 1/26?',
#  'Which tenant missed rent on 2/2?')
#
# ('0.80',
#  '(e_id, q1)=(283, 3), (283, 4)',
#  'What is the email address of Phillip Allen?',
#  'What is the phone number of Phillip Allen?')
#
# ('0.80',
#  '(e_id, q1)=(304, 0), (304, 5)',
#  'What is the estimated cost of the project according to Phillip Allen?',
#  'What does Phillip Allen recommend regarding the total cost estimates for the '
#  'project?')
#
# ('0.88',
#  '(e_id, q1)=(334, 0), (334, 3)',
#  "What is Mike's retention payment amount?",
#  'When will Mike receive his retention payment?')

# %%
TO_KEEP = [
    '(e_id, q1)=(277, 2), (277, 3)'
] # above 0.83

TO_DELETE = [
    
]

# %%
pprint(set(bad_questions))
# Out:
# {"How much are the builders' bids for the house project?",
#  'What does Phillip refer to himself as in the email?',
#  "What is Phillip's name in the email?",
#  'What is the cell phone number to reach Phillip Allen?',
#  'What is the email address of Phillip Allen?',
#  'What is the fax number provided in the email?',
#  'What is the intended shape of the kitchen island?',
#  'What is the name of the person addressed in the email?',
#  'What is the overall dimension of the house mentioned in the email?',
#  'What is the purpose of the email?',
#  'What is the subject of the email?',
#  'What material does Paul Allen suggest for the exterior of the house?',
#  'What style of house is Paul Allen aiming for?',
#  'What time is the meeting scheduled for?',
#  'What type of roof does Paul Allen want for the house?',
#  'When will Phillip talk to Lucy again?',
#  'Who is the email addressed to?',
#  'Who is the recipient of the email?',
#  'Who is the sender of the email?',
#  'Who sent the email?'}

# %% [markdown]
# # Let's find all bad questions that look alike using Embedding

# %%
bad_questions.extend([
    'What is the email address of Phillip Allen?',
    'What is the phone number of Phillip Allen?',
    "What is Phillip Allen's work phone number?",
    'What is the cell phone number for Phillip Allen?',
    'What day is the meeting scheduled for?',
    'What time is the meeting scheduled for?',
    'who is the sender of the email?',
    "what is the sender's name as mentioned in the email?"
])

# %%
bad_question_embeddings = await tqdm_asyncio.gather(*[
    cached_embedding_with_retry(input=bad_question, model=EMBED_MODEL)
    for bad_question in set(bad_questions)
])
# Out:
# 100%|██████████| 26/26 [00:00<00:00, 545.04it/s]

# %%
bad_questions_set = set(bad_questions)

# %%
questions_to_delete = set()
questions_to_review = []

for question in questions_with_embeddings:
    if question['question'] in bad_questions_set:
        questions_to_delete.add((question['id_message'], question['id_question']))
    else:
        q_embed = question['embedding']
        for i, bad_question in enumerate(bad_questions_set):
            cos_sim = embedding_cosine_sim(bad_question_embeddings[i], q_embed)
            if cos_sim > 0.8:
                questions_to_review.append(question)
                continue

# %%
len(questions_to_review)
# Out:
# 33

# %%
def pick_field_from_dict(dict_, keys: set[str | int]):
    return {k:v for k, v in dict_.items() if k in keys}

# %%
_questions_to_review = [pick_field_from_dict(q, {'id_message', 'id_question', 'question'}) for q in questions_to_review]

# %%
pprint(_questions_to_review)
# Out:
# [{'id_message': 32,
#   'id_question': 4,
#   'question': "What is Phillip's name mentioned in the email?"},
#  {'id_message': 40,
#   'id_question': 3,
#   'question': 'What is the email address for Phillip Allen?'},
#  {'id_message': 40,
#   'id_question': 3,
#   'question': 'What is the email address for Phillip Allen?'},
#  {'id_message': 42,
#   'id_question': 5,
#   'question': 'Who is the recipient of this email?'},
#  {'id_message': 42,
#   'id_question': 5,
#   'question': 'Who is the recipient of this email?'},
#  {'id_message': 51,
#   'id_question': 5,
#   'question': 'What is the primary purpose of the email?'},
#  {'id_message': 99,
#   'id_question': 2,
#   'question': 'What time is it for the meeting?'},
#  {'id_message': 99,
#   'id_question': 4,
#   'question': 'When is the meeting scheduled for?'},
#  {'id_message': 99,
#   'id_question': 4,
#   'question': 'When is the meeting scheduled for?'},
#  {'id_message': 129,
#   'id_question': 2,
#   'question': 'Who is Phillip addressing in the email?'},
#  {'id_message': 139,
#   'id_question': 5,
#   'question': "What is the sender's name in the email?"},
#  {'id_message': 139,
#   'id_question': 5,
#   'question': "What is the sender's name in the email?"},
#  {'id_message': 139,
#   'id_question': 5,
#   'question': "What is the sender's name in the email?"},
#  {'id_message': 181,
#   'id_question': 3,
#   'question': "What is the sender's email address?"},
#  {'id_message': 181,
#   'id_question': 3,
#   'question': "What is the sender's email address?"},
#  {'id_message': 185,
#   'id_question': 5,
#   'question': 'who is being addressed in the email?'},
#  {'id_message': 185,
#   'id_question': 5,
#   'question': 'who is being addressed in the email?'},
#  {'id_message': 215,
#   'id_question': 5,
#   'question': "What is the email sender's name as mentioned in the email?"},
#  {'id_message': 215,
#   'id_question': 5,
#   'question': "What is the email sender's name as mentioned in the email?"},
#  {'id_message': 220,
#   'id_question': 4,
#   'question': 'Who are the recipients of the email?'},
#  {'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 246,
#   'id_question': 2,
#   'question': 'Where is Phillip Allen located?'},
#  {'id_message': 295,
#   'id_question': 4,
#   'question': "What is Phillip Allen's extension number?"},
#  {'id_message': 311,
#   'id_question': 4,
#   'question': "What is the sender's name?"},
#  {'id_message': 334, 'id_question': 4, 'question': 'Who sent this email?'},
#  {'id_message': 334, 'id_question': 4, 'question': 'Who sent this email?'},
#  {'id_message': 374,
#   'id_question': 4,
#   'question': "What is the email sender's name?"},
#  {'id_message': 374,
#   'id_question': 4,
#   'question': "What is the email sender's name?"},
#  {'id_message': 393,
#   'id_question': 3,
#   'question': 'Who is the author of the email?'},
#  {'id_message': 393,
#   'id_question': 4,
#   'question': 'What was the purpose of the email?'}]

# %%
{
    "id_message": 246,
    "id_question": 2,
    "question": 'Where is Phillip Allen located?'
}
{
    'id_message': 226,
    'id_question': 0,
    'question': 'What is the home number to call Phillip Allen with questions?'}
# Out:
# {'id_message': 226,
#  'id_question': 0,
#  'question': 'What is the home number to call Phillip Allen with questions?'}

# %%
_questions_to_delete_after_review = [q for q in _questions_to_review if (q['id_message'], q['id_question']) in {(246, 2), (226, 0)}]

# %%
_questions_to_delete_after_review
# Out:
# [{'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 226,
#   'id_question': 0,
#   'question': 'What is the home number to call Phillip Allen with questions?'},
#  {'id_message': 246,
#   'id_question': 2,
#   'question': 'Where is Phillip Allen located?'}]

# %%
questions_to_delete.update({(question['id_message'], question['id_question']) for question in _questions_to_delete_after_review})

# %%
len(questions_to_delete)
# Out:
# 77

# %%
questions_to_improve = [
    'which individual is mentioned in relation to kim olinger?', # no information about the project; too vague
    'What does Phillip consider for owner financing?', # Phillip would not speak at the 3rd person
    'What does Phillip consider for owner financing?',
    'What are the terms that Phillip is considering for owner financing?',
    'What would the 6 month payout be per month?', # too vague
    'What formula should be used in column e?', # missing information
    'What should be the formula in column h?', # missing information
    'What is the price Phillip is prepared to pay for sagewood?', # Phillip would not speak at the 3rd person
    'Does Phillip indicate he is prepared to pay more than 2.7 for sagewood?', # Phillip would not speak at the 3rd person
    "How much higher is Phillip Allen's bid per square foot compared to Reagan's units under construction?", # Phillip would not speak at the 3rd person
    'What is the price per square foot that Phillip Allen is bidding compared to the units sold by Reagan?', # Phillip would not speak at the 3rd person
    'What does Phillip want to know about the investment dollars timeline?', # Phillip would not speak at the 3rd person
    'What does Phillip want to get a feel for regarding the investment dollars?', # Phillip would not speak at the 3rd person
    'What day and time did Phillip suggest for the meeting?', # Phillip would not speak at the 3rd person; not specific enough
    'What specific time did Phillip propose for the meeting?', # Phillip would not speak at the 3rd person; not specific enough
    'Which tenant missed rent on 1/26?', # the exact date should rather be a range of date or a month 
    'Which tenant missed rent on 2/2?', # the exact date should rather be a range of date or a month
]

# %% [markdown]
# # Verifying duplicates

# %% [markdown]
# ## Prompt Template

# %%
from pydantic import BaseModel
from enum import Enum

class DuplicateVerdictEnum(Enum):
    is_duplicate = "same"
    is_not_duplicate = "different"

class DuplicateVerdict(BaseModel):
    concise_reasoning: str
    verdict: DuplicateVerdictEnum

# %%
from textwrap import dedent
from jinja2 import Template

_system_prompt_template = Template(dedent(
    """\
    Your task is to assess if 2 questions are close enough to have the same answers.

    You'll answer in JSON by respecting the following schema:
    ```ts
    {
        concise_reasoning: str
        verdict: "{{ is_duplicate }}" | "{{ is_not_duplicate }}"
    }
    ```
    """
))

# %%
_check_system_prompt = _system_prompt_template.render(
    is_duplicate=DuplicateVerdictEnum.is_duplicate.value,
    is_not_duplicate=DuplicateVerdictEnum.is_not_duplicate.value,
)

# %%
prompt_template = Template(dedent(
    """\
    Do those two questions are likely to have the same answer and can be considered duplicates of each other?

    <question 1>
    {{ question_1 }}
    </question 1>

    <question 2>
    {{ question_2 }}
    </question 2>
    
    First concisely reason step by step, then provide your final verdict.
    """
))

# %%
_check_prompt = prompt_template.render(
    question_1="What is the phone number of Paul Allen for contact?",
    question_2="What is the cell phone number of Paul Allen?"
)

# %% [markdown]
# ## LLM

# %%
LLM_MODEL = GPT4O_MINI

_check_result = await cached_chat_completion_parsed_with_retry(
    model=LLM_MODEL,
    messages=[
        system(_check_system_prompt),
        user(_check_prompt),
    ],
    max_completion_tokens=2000,
    response_format=DuplicateVerdict
)

# %%
_check_result.choices[0].message.parsed
# Out:
# DuplicateVerdict(concise_reasoning='The first asks for a general contact phone number (which could be an office or main line), while the second specifically asks for a cell phone number. They likely refer to different numbers.', verdict=<DuplicateVerdictEnum.is_not_duplicate: 'different'>)

# %%
len(likely_duplicates)
# Out:
# 32

# %%
tasks = []

for (e_id, q1_id, q2_id) in likely_duplicates:
    question_1 = index_for_questions_with_embeddings[e_id][q1_id]['question']
    question_2 = index_for_questions_with_embeddings[e_id][q2_id]['question']
    prompt = prompt_template.render(
        question_1=question_1,
        question_2=question_2
    )
    
    task = cached_chat_completion_parsed_with_retry(
        model=LLM_MODEL,
        messages=[
            system(_check_system_prompt),
            user(prompt),
        ],
        max_completion_tokens=2000,
        response_format=DuplicateVerdict
    )
    tasks.append(task)

# %%
results = await tqdm_asyncio.gather(*tasks)
# Out:
# 100%|██████████| 32/32 [00:00<00:00, 540.49it/s]

# %%
"""
counter = 0

for (e_id, q1_id, q2_id), result in zip(likely_duplicates, results):
    result = result.choices[0].message.parsed
    if result.verdict == DuplicateVerdictEnum.is_duplicate:
        question_1 = index_for_questions_with_embeddings[e_id][q1_id]['question']
        question_2 = index_for_questions_with_embeddings[e_id][q2_id]['question']
        print(
            (e_id, q1_id, q2_id), '\n',
            question_1, '\n',
            question_2, '\n',
            result.concise_reasoning, '\n',
            '\n'
        )
        counter += 1
"""
# Out:
# (65, 1, 4)
#  What does Phillip consider for owner financing?
#  What are the terms that Phillip is considering for owner financing?
#  Both questions ask for the specific terms Phillip is considering in an owner-financing arrangement, so they seek the same information.
#
#
# (66, 0, 5)
#  What products are routed to nw basis?
#  Which products are mentioned in relation to nw basis?
#  Both questions seek the set of products associated with “nw basis” and would yield the same answer.
#
#
# (150, 0, 3)
#  What is the price per duplex for the 22 units sold by Reagan Lehmann?
#  What is the price per duplex for the units that Reagan is selling?
#  Both questions ask for the price per duplex set by Reagan for her units; the only difference is referring to “22 units sold” vs. “units she’s selling,” but they seek the identical figure.
#
#
# (185, 2, 3)
#  who is the sender of the email?
#  what is the sender's name as mentioned in the email?
#  Both ask for the identity of the email sender and would yield the same information (the sender’s name).
#
#
# (203, 3, 4)
#  What does Phillip want to know about the investment dollars timeline?
#  What does Phillip want to get a feel for regarding the investment dollars?
#  Both ask the same thing about what Phillip wants concerning the investment dollars’ timeline (i.e. getting a feel for timing), only phrased differently.

# %%
counter
# Out:
# 5

# %%
for (e_id, q1_id, q2_id), result in zip(likely_duplicates, results):
    result = result.choices[0].message.parsed
    if result.verdict == DuplicateVerdictEnum.is_duplicate:
        questions_to_delete.add(
            (e_id, q2_id)
        )

# %%
print(f"Pourcentage of questions to delete :{len(questions_to_delete) / len(questions_with_embeddings) * 100: .2f} %", "")
# Out:
# Pourcentage of questions to delete : 7.03 %

# %%
deduplicated_questions = []

for each in questions_with_embeddings:
    e_id = each['id_message']
    q_id = each['id_question']
    question = each['question']
    if (e_id, q_id) not in questions_to_delete:
        e_id = emails.iloc[e_id]['Message-ID']
        deduplicated_questions.append((e_id, question))

# %%
import json

with open('deduplicated_questions.json', 'w') as f:
    json.dump(deduplicated_questions, f)

# %%
with open('deduplicated_questions.json', 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# [['<13537630.1075855669909.JavaMail.evans@thyme',
#   'What is the bid amount for Sagewood?'],
#  ['<13537630.1075855669909.JavaMail.evans@thyme',
#   'What rate is being requested for Sagewood?'],
#  ['<13537630.1075855669909.JavaMail.evans@thyme',
#   'What is the term dependent on for the Sagewood bid?'],
#  ['<13537630.1075855669909.JavaMail.evans@thyme',
#   'What is the maximum rate mentioned for the Sagewood bid?'],
#  ['<13537630.1075855669909.JavaMail.evans@thyme',
#   'What asset is being referenced in the bid?'],
#  ['<21846431.1075855673215.JavaMail.evans@thyme',
#   'Who are the two analysts mentioned in the email?'],
#  ['<21846431.1075855673215.JavaMail.evans@thyme',
#   'Who will represent Matt Lenhart?'],
#  ['<21846431.1075855673215.JavaMail.evans@thyme',
#   'In what group did Vishal Apte work for the first 9 months?'],
#  ['<21846431.1075855673215.JavaMail.evans@thyme',
#   "Who did Paul Allen speak to regarding Vishal's performance?"],
#  ['<21846431.1075855673215.JavaMail.evans@thyme',
#   'What category was Vishal agreed upon to be in?'],
#  ['<21846431.1075855673215.JavaMail.evans@thyme',
#   'When did Vishal join the group?'],
#  ['<16083605.1075855673018.JavaMail.evans@thyme',
#   'Who should authorize and forward the information to Tara Sweitzer?'],
#  ['<16083605.1075855673018.JavaMail.evans@thyme',
#   'What type of products will the traders be managing?'],
#  ['<16083605.1075855673018.JavaMail.evans@thyme',
#   'How long is the timeframe for the physical products the traders will manage?'],
#  ['<16083605.1075855673018.JavaMail.evans@thyme',
#   'To whom should access and passwords be granted for executing book to book trades?'],
#  ['<16083605.1075855673018.JavaMail.evans@thyme',
#   'What should be the restriction on the execution authority for the traders?'],
#  ['<16083605.1075855673018.JavaMail.evans@thyme',
#   'Who are the traders mentioned in the email?'],
#  ['<30997906.1075855672973.JavaMail.evans@thyme',
#   'What will they need more of at Ehrenberg?'],
#  ['<30997906.1075855672973.JavaMail.evans@thyme',
#   'What is Ehrenberg referred to in the email?'],
#  ['<30997906.1075855672973.JavaMail.evans@thyme',
#   'What year is mentioned in relation to the demand forecast for SoCal?'],
#  ['<30997906.1075855672973.JavaMail.evans@thyme',
#   'What does the forecast indicate about gas demand at Ehrenberg compared to 98 or 99?'],
#  ['<1678403.1075855672927.JavaMail.evans@thyme',
#   'What products are being requested for approval?'],
#  ['<1678403.1075855672927.JavaMail.evans@thyme',
#   'When are customers expecting to see the products?'],
#  ['<1678403.1075855672927.JavaMail.evans@thyme',
#   'Who should the approved products be forwarded to?'],
#  ['<1678403.1075855672927.JavaMail.evans@thyme',
#   'What is the date mentioned for customer expectations?'],
#  ['<1678403.1075855672927.JavaMail.evans@thyme',
#   'Which physical products are listed for PG&E?'],
#  ['<1678403.1075855672927.JavaMail.evans@thyme',
#   'Which physical products are listed for SoCal border?'],
#  ['<18449022.1075855672884.JavaMail.evans@thyme',
#   'What is the date and time for the changes to be made?'],
#  ['<18449022.1075855672884.JavaMail.evans@thyme',
#   'Who is the master user for ft-west after the change?'],
#  ['<18449022.1075855672884.JavaMail.evans@thyme',
#   'Who is the master user for im-west after the change?'],
#  ['<18449022.1075855672884.JavaMail.evans@thyme',
#   'What action is requested to be taken on both existing profiles?'],
#  ['<24686087.1075855672797.JavaMail.evans@thyme',
#   'What are the actual flows x gas daily spreads for January?'],
#  ['<24686087.1075855672797.JavaMail.evans@thyme',
#   'What is the estimated cost to unwind hedges?'],
#  ['<24686087.1075855672797.JavaMail.evans@thyme',
#   'What is the suggested offer range to pay?'],
#  ['<24686087.1075855672797.JavaMail.evans@thyme',
#   'What is the January value from the original bid?'],
#  ['<24686087.1075855672797.JavaMail.evans@thyme',
#   'How should we negotiate with El Paso according to Phillip?'],
#  ['<24686087.1075855672797.JavaMail.evans@thyme',
#   'What are the two types of spreads mentioned in the email?'],
#  ['<17809956.1075855672733.JavaMail.evans@thyme',
#   'What is documented in the email?'],
#  ['<17809956.1075855672733.JavaMail.evans@thyme',
#   'Who approved granting executing ids?'],
#  ['<17809956.1075855672733.JavaMail.evans@thyme',
#   'To whom were the executing ids granted?'],
#  ['<17809956.1075855672733.JavaMail.evans@thyme',
#   'What is thanked for assistance?'],
#  ['<17809956.1075855672733.JavaMail.evans@thyme',
#   'What is the relation of Phillip Allen to the execution id approval?'],
#  ['<13297455.1075855672711.JavaMail.evans@thyme',
#   'What time will the updated curves be sent?'],
#  ['<13297455.1075855672711.JavaMail.evans@thyme',
#   'Who is to be involved in the process?'],
#  ['<13297455.1075855672711.JavaMail.evans@thyme', 'Who was out today?'],
#  ['<13297455.1075855672711.JavaMail.evans@thyme',
#   'What date will the updated curves be sent?'],
#  ['<13297455.1075855672711.JavaMail.evans@thyme',
#   'What is the reason for the slow turnaround?'],
#  ['<14186864.1075855672647.JavaMail.evans@thyme',
#   'who is the person to talk to about moving kim olinger to a different rc code?'],
#  ['<14186864.1075855672647.JavaMail.evans@thyme',
#   'what is being discussed in terms of kim olinger?'],
#  ['<14186864.1075855672647.JavaMail.evans@thyme',
#   'what action does the email suggest regarding kim olinger?'],
#  ['<14186864.1075855672647.JavaMail.evans@thyme',
#   'which individual is mentioned in relation to kim olinger?'],
#  ['<14186864.1075855672647.JavaMail.evans@thyme',
#   'what is the context of the email regarding rc code?'],
#  ['<14186864.1075855672647.JavaMail.evans@thyme',
#   'who should be consulted for the action mentioned?'],
#  ['<9252147.1075855672604.JavaMail.evans@thyme',
#   'What is the phone number for the credit desk?'],
#  ['<9252147.1075855672604.JavaMail.evans@thyme',
#   'Who should George call regarding the financials for acn power?'],
#  ['<9252147.1075855672604.JavaMail.evans@thyme',
#   'What financials have not been received?'],
#  ['<9252147.1075855672604.JavaMail.evans@thyme',
#   'What is the full name of Paul Allen in the email?'],
#  ['<9252147.1075855672604.JavaMail.evans@thyme',
#   'What does Phillip Allen request George to do?'],
#  ['<9132316.1075855672347.JavaMail.evans@thyme',
#   "Who did Tara set up with executable ID's?"],
#  ['<9132316.1075855672347.JavaMail.evans@thyme',
#   'What did Phillip thank Tara for?'],
#  ['<9132316.1075855672347.JavaMail.evans@thyme',
#   "What are the names of the individuals mentioned in Phillip's email?"],
#  ['<9132316.1075855672347.JavaMail.evans@thyme',
#   'What rights did Phillip mention are fine?'],
#  ['<2553402.1075855672271.JavaMail.evans@thyme',
#   'What date does Paul Allen suggest to close on?'],
#  ['<2553402.1075855672271.JavaMail.evans@thyme',
#   'What action does Paul Allen propose in the email?'],
#  ['<12172542.1075855672250.JavaMail.evans@thyme',
#   'How much did Phillip transfer out of the checking account?'],
#  ['<12172542.1075855672250.JavaMail.evans@thyme',
#   'When did Phillip transfer the $10,000?'],
#  ['<12172542.1075855672250.JavaMail.evans@thyme',
#   'What day will Phillip call Mary?'],
#  ['<12172542.1075855672250.JavaMail.evans@thyme',
#   'What is the date referenced for the transfer?'],
#  ['<12172542.1075855672250.JavaMail.evans@thyme',
#   "What is Phillip's name mentioned in the email?"],
#  ['<13567328.1075855672164.JavaMail.evans@thyme',
#   'Is it ok to let the deposit rollover on #13?'],
#  ['<13567328.1075855672164.JavaMail.evans@thyme',
#   'What condition is required for the deposit to rollover on #13?'],
#  ['<13567328.1075855672164.JavaMail.evans@thyme',
#   'What happens if there is no interruption in rent?'],
#  ['<23338509.1075855672034.JavaMail.evans@thyme',
#   'Who should be removed from rc #768?'],
#  ['<23338509.1075855672034.JavaMail.evans@thyme',
#   'What is the action requested in the email?'],
#  ['<23338509.1075855672034.JavaMail.evans@thyme',
#   'What is the email address for Phillip Allen?'],
#  ['<23338509.1075855672034.JavaMail.evans@thyme',
#   'What is the rc number mentioned in the email?'],
#  ['<23338509.1075855672034.JavaMail.evans@thyme',
#   'What are the names mentioned for removal?'],
#  ['<4100112.1075855672012.JavaMail.evans@thyme',
#   'Go ahead and level the floor in #2.'],
#  ['<21060855.1075855671990.JavaMail.evans@thyme',
#   'What is the underlying goal mentioned in the email?'],
#  ['<21060855.1075855671990.JavaMail.evans@thyme',
#   'When does Phillip want to schedule a meeting to go over the items?'],
#  ['<21060855.1075855671990.JavaMail.evans@thyme',
#   'What specific reports does Phillip want to improve for the west desk?'],
#  ['<21060855.1075855671990.JavaMail.evans@thyme',
#   'What does Phillip want the P&L reports to accurately represent?'],
#  ['<21060855.1075855671990.JavaMail.evans@thyme',
#   'What should the position managers and P&L reports estimate?'],
#  ['<21060855.1075855671990.JavaMail.evans@thyme',
#   'Who is the recipient of this email?'],
#  ['<22557164.1075855671713.JavaMail.evans@thyme',
#   'Can you create an e-mail list to distribute your reports everyday to the west desk?'],
#  ['<22557164.1075855671713.JavaMail.evans@thyme',
#   'What should the e-mail list include?'],
#  ['<22557164.1075855671713.JavaMail.evans@thyme',
#   'Who are the people listed in the email?'],
#  ['<22557164.1075855671713.JavaMail.evans@thyme',
#   "What is Phillip's last name?"],
#  ['<22557164.1075855671713.JavaMail.evans@thyme',
#   'What is the main action requested in the email?'],
#  ['<22557164.1075855671713.JavaMail.evans@thyme',
#   'Are the reports to be distributed every day?'],
#  ['<1308680.1075855671605.JavaMail.evans@thyme',
#   'Who should be granted access to manage financial products?'],
#  ['<1308680.1075855671605.JavaMail.evans@thyme',
#   'What type of swaps are being made?'],
#  ['<1308680.1075855671605.JavaMail.evans@thyme',
#   'What is the first name of the person sending the email?'],
#  ['<1308680.1075855671605.JavaMail.evans@thyme',
#   'What is the last name of the sender?'],
#  ['<1308680.1075855671605.JavaMail.evans@thyme',
#   'What is the primary purpose of the email?'],
#  ['<31751710.1075855671584.JavaMail.evans@thyme',
#   'Could we set up an inspection for this Friday at 2:00?'],
#  ['<31751710.1075855671584.JavaMail.evans@thyme',
#   'What time is the inspection set for?'],
#  ['<31751710.1075855671584.JavaMail.evans@thyme',
#   'What day is the inspection scheduled?'],
#  ['<31751710.1075855671584.JavaMail.evans@thyme',
#   'What is in the mail according to Phillip?'],
#  ['<31751710.1075855671584.JavaMail.evans@thyme',
#   'What property is listed in the email?'],
#  ['<27598897.1075855671563.JavaMail.evans@thyme',
#   'What agreement does Enron have that is exclusive?'],
#  ['<27598897.1075855671563.JavaMail.evans@thyme',
#   'Which company are the options being executed with?'],
#  ['<27598897.1075855671563.JavaMail.evans@thyme',
#   'What service account does Phillip want to reach?'],
#  ['<27598897.1075855671563.JavaMail.evans@thyme',
#   'What must Phillip do in order to get to the premier service account?'],
#  ['<13455757.1075855671541.JavaMail.evans@thyme',
#   'What date will we be there?'],
#  ['<13455757.1075855671541.JavaMail.evans@thyme',
#   'Who is bringing the paperwork?'],
#  ['<18933739.1075855671392.JavaMail.evans@thyme',
#   'What did Gary agree about the foundation work on #2 & #3?'],
#  ['<18933739.1075855671392.JavaMail.evans@thyme',
#   'Who can do whatever work on #2 according to Gary?'],
#  ['<18933739.1075855671392.JavaMail.evans@thyme',
#   'What did Paul Allen work on this weekend?'],
#  ['<18933739.1075855671392.JavaMail.evans@thyme',
#   'How long does Paul Allen need to finish the books?'],
#  ['<18933739.1075855671392.JavaMail.evans@thyme',
#   'Who will Paul Allen call in a day or so?'],
#  ['<18933739.1075855671392.JavaMail.evans@thyme',
#   'Which project will Gary and Wade focus on after #2 and #3?'],
#  ['<21006708.1075855671285.JavaMail.evans@thyme',
#   'Did you meet with SWG on April 27th?'],
#  ['<21006708.1075855671285.JavaMail.evans@thyme',
#   'Are there any other asset management targets in the west?'],
#  ['<10469998.1075855671218.JavaMail.evans@thyme',
#   'What did you receive from dawn?'],
#  ['<10469998.1075855671218.JavaMail.evans@thyme',
#   'What should dawn continue to send?'],
#  ['<10469998.1075855671218.JavaMail.evans@thyme',
#   "How often should dawn send the p&l's?"],
#  ['<10469998.1075855671218.JavaMail.evans@thyme', 'Who is thanking dawn?'],
#  ['<10469998.1075855671218.JavaMail.evans@thyme',
#   'What is the name associated with the email?'],
#  ['<14437034.1075855671174.JavaMail.evans@thyme',
#   'What is the downpayment percentage that Phillip mentioned in the email?'],
#  ['<14437034.1075855671174.JavaMail.evans@thyme',
#   'What does Phillip consider for owner financing?'],
#  ['<14437034.1075855671174.JavaMail.evans@thyme',
#   'What factors does Phillip mention regarding credit risk?'],
#  ['<14437034.1075855671174.JavaMail.evans@thyme',
#   'What does Phillip want to know about the land?'],
#  ['<20485107.1075855671129.JavaMail.evans@thyme',
#   'What products are routed to nw basis?'],
#  ['<20485107.1075855671129.JavaMail.evans@thyme',
#   'Who is the book set up for?'],
#  ['<20485107.1075855671129.JavaMail.evans@thyme',
#   'Who should be contacted with questions about the ft-new texas call?'],
#  ['<20485107.1075855671129.JavaMail.evans@thyme',
#   'What is the extension number for contacting Todd Richardson?'],
#  ['<20485107.1075855671129.JavaMail.evans@thyme',
#   'What is the new book set up for Frank Ermis?'],
#  ['<8827549.1075855671107.JavaMail.evans@thyme',
#   'Did you get set up on the checking account?'],
#  ['<8827549.1075855671107.JavaMail.evans@thyme', 'What happened that day?'],
#  ['<8827549.1075855671107.JavaMail.evans@thyme',
#   'Which apartments did you and Wade work on each day?'],
#  ['<8827549.1075855671107.JavaMail.evans@thyme',
#   'What information should Lucy email me about?'],
#  ['<8827549.1075855671107.JavaMail.evans@thyme',
#   'Are there any new vacancies?'],
#  ['<8827549.1075855671107.JavaMail.evans@thyme',
#   'Who should email me every day?'],
#  ['<11314440.1075855671086.JavaMail.evans@thyme',
#   'When will Paul Allen be in Seguin?'],
#  ['<11314440.1075855671086.JavaMail.evans@thyme',
#   'What will Paul Allen discuss with Lucy regarding Wade?'],
#  ['<11314440.1075855671086.JavaMail.evans@thyme',
#   'What time will the office be open until on Memorial Day?'],
#  ['<11314440.1075855671086.JavaMail.evans@thyme',
#   'Who is Paul Allen addressing in this email?'],
#  ['<11314440.1075855671086.JavaMail.evans@thyme',
#   'What action will Paul Allen take regarding the bank?'],
#  ['<1670364.1075855671043.JavaMail.evans@thyme',
#   'What is the total amount if both balances are added together?'],
#  ['<1670364.1075855671043.JavaMail.evans@thyme',
#   'What would the 6 month payout be per month?'],
#  ['<1670364.1075855671043.JavaMail.evans@thyme',
#   'What would the 12 month payout be per month?'],
#  ['<1670364.1075855671043.JavaMail.evans@thyme',
#   'How many hours per week does Phillip want Mary to work?'],
#  ['<1670364.1075855671043.JavaMail.evans@thyme',
#   'What is the hourly rate offered to Mary for her work?'],
#  ['<1670364.1075855671043.JavaMail.evans@thyme',
#   'What can be applied to the loan?'],
#  ['<26423527.1075855670975.JavaMail.evans@thyme',
#   'What is the amount of the expansion mentioned in the email?'],
#  ['<26423527.1075855670975.JavaMail.evans@thyme',
#   'How many jobs will the expansion add in Burnet?'],
#  ['<26423527.1075855670975.JavaMail.evans@thyme',
#   'What price is Phillip tempted to hold for the land per acre?'],
#  ['<26423527.1075855670975.JavaMail.evans@thyme',
#   'Does Phillip mention that owner financing would still work?'],
#  ['<26423527.1075855670975.JavaMail.evans@thyme',
#   'When will Phillip respond to the offer?'],
#  ['<35511.1075855670954.JavaMail.evans@thyme',
#   'What do you think about being open until noon on Saturday?'],
#  ['<35511.1075855670954.JavaMail.evans@thyme',
#   'What is better for sending updates, a log on paper or on the computer?'],
#  ['<35511.1075855670954.JavaMail.evans@thyme',
#   'What is more convenient for collecting rent and showing open apartments?'],
#  ['<35511.1075855670954.JavaMail.evans@thyme',
#   'Can we adjust office hours on another day?'],
#  ['<4871446.1075855670783.JavaMail.evans@thyme',
#   'Who does Phillip want to speak to directly?'],
#  ['<4871446.1075855670783.JavaMail.evans@thyme',
#   'What tasks will Gary direct Wade on?'],
#  ['<4871446.1075855670783.JavaMail.evans@thyme',
#   'What will Lucy provide Gary regarding maintenance?'],
#  ['<4871446.1075855670783.JavaMail.evans@thyme',
#   'When does Phillip plan to call Lucy to discuss items from the office?'],
#  ['<4871446.1075855670783.JavaMail.evans@thyme',
#   'Does Phillip think Mary will need to come in on any more Fridays?'],
#  ['<4871446.1075855670783.JavaMail.evans@thyme',
#   'When might Phillip stop by the office?'],
#  ['<3536013.1075855670762.JavaMail.evans@thyme',
#   'What will they offer online at a fixed price?'],
#  ['<3536013.1075855670762.JavaMail.evans@thyme',
#   'What is the risk mentioned in the email?'],
#  ['<3536013.1075855670762.JavaMail.evans@thyme',
#   'What will they do once their sales are large enough?'],
#  ['<3536013.1075855670762.JavaMail.evans@thyme',
#   "What is the current provider's price situation?"],
#  ['<3536013.1075855670762.JavaMail.evans@thyme',
#   "What is Phillip's best guess regarding the new company's pricing strategy?"],
#  ['<3536013.1075855670762.JavaMail.evans@thyme',
#   'Who did Phillip email to get the exact details?'],
#  ['<29561577.1075855670577.JavaMail.evans@thyme',
#   'What will Phillip mark up this weekend?'],
#  ['<29561577.1075855670577.JavaMail.evans@thyme',
#   'What is the 4th for Lucy and Wade?'],
#  ['<29561577.1075855670577.JavaMail.evans@thyme',
#   'What will Phillip ask his dad about?'],
#  ['<29561577.1075855670577.JavaMail.evans@thyme',
#   "What is Phillip's relationship to Lucy?"],
#  ['<29561577.1075855670577.JavaMail.evans@thyme',
#   "What was Lucy's job status according to Phillip?"],
#  ['<32290381.1075855670533.JavaMail.evans@thyme',
#   'What did Matt send to Tim?'],
#  ['<32290381.1075855670533.JavaMail.evans@thyme',
#   'Who expressed concern over the reliability of the WSCC data?'],
#  ['<32290381.1075855670533.JavaMail.evans@thyme',
#   'What are the two types of data mentioned in the email?'],
#  ['<32290381.1075855670533.JavaMail.evans@thyme',
#   'What does Phillip think about the WSCC data?'],
#  ['<32290381.1075855670533.JavaMail.evans@thyme',
#   'What does Phillip ask Tim to do regarding the WSCC data?'],
#  ['<30396166.1075855670470.JavaMail.evans@thyme',
#   'What did Matt Lutz was supposed to email Paul Allen?'],
#  ['<30396166.1075855670470.JavaMail.evans@thyme',
#   'When is the estimated closing date?'],
#  ['<30396166.1075855670470.JavaMail.evans@thyme',
#   'Who was spoken to regarding the details?'],
#  ['<30396166.1075855670470.JavaMail.evans@thyme',
#   'What should Jeff follow up with Matt Lutz about?'],
#  ['<30396166.1075855670470.JavaMail.evans@thyme',
#   'What else does Paul Allen need to be doing?'],
#  ['<14428197.1075855670448.JavaMail.evans@thyme',
#   'What is the document attached to the email?'],
#  ['<14428197.1075855670448.JavaMail.evans@thyme',
#   'What is the purpose of the Excel file that was sent?'],
#  ['<14428197.1075855670448.JavaMail.evans@thyme',
#   'What can the additional principal reduction be used for?'],
#  ['<14428197.1075855670448.JavaMail.evans@thyme',
#   'Who should confirm receipt of the email?'],
#  ['<14428197.1075855670448.JavaMail.evans@thyme',
#   'What type of form is included in the attached Word document?'],
#  ['<23928221.1075855670300.JavaMail.evans@thyme',
#   'How about Tuesday at 11:15?'],
#  ['<23928221.1075855670300.JavaMail.evans@thyme', 'Where should I meet you?'],
#  ['<23928221.1075855670300.JavaMail.evans@thyme',
#   'In front of what building will we meet?'],
#  ['<24727528.1075855670278.JavaMail.evans@thyme',
#   'What does Celeste need help with?'],
#  ['<24727528.1075855670278.JavaMail.evans@thyme',
#   'How many associates/analysts are needed for the west gas trading desk?'],
#  ['<24727528.1075855670278.JavaMail.evans@thyme',
#   'Who left Celeste a voicemail?'],
#  ['<24727528.1075855670278.JavaMail.evans@thyme',
#   'What is the extension number provided in the email?'],
#  ['<10434631.1075855670105.JavaMail.evans@thyme', 'What time works today?'],
#  ['<10434631.1075855670105.JavaMail.evans@thyme',
#   'When does the scheduled time occur?'],
#  ['<10434631.1075855670105.JavaMail.evans@thyme',
#   'What time is it for the meeting?'],
#  ['<10434631.1075855670105.JavaMail.evans@thyme',
#   'What is the confirmed meeting time?'],
#  ['<10434631.1075855670105.JavaMail.evans@thyme',
#   'When is the meeting scheduled for?'],
#  ['<10434631.1075855670105.JavaMail.evans@thyme',
#   'What time does it still work?'],
#  ['<5850608.1075855670018.JavaMail.evans@thyme',
#   "What was Wade's number one priority?"],
#  ['<5850608.1075855670018.JavaMail.evans@thyme',
#   'What does Lucy need to hold the tenants to a standard regarding vehicles?'],
#  ['<5850608.1075855670018.JavaMail.evans@thyme',
#   'What type of vehicle does Wade consider buying?'],
#  ['<5850608.1075855670018.JavaMail.evans@thyme',
#   "How will Phillip vouch for Wade's income?"],
#  ['<5850608.1075855670018.JavaMail.evans@thyme',
#   'When does Wade need to take care of his vehicle situation?'],
#  ['<21139938.1075855669867.JavaMail.evans@thyme',
#   'What is the only long term deal in the west mentioned in the email?'],
#  ['<21139938.1075855669867.JavaMail.evans@thyme',
#   'Until what year is the PGT transport deal valid?'],
#  ['<21139938.1075855669867.JavaMail.evans@thyme',
#   'What company is associated with the long term deal mentioned?'],
#  ['<21139938.1075855669867.JavaMail.evans@thyme',
#   'What kind of deal does Phillip Allen refer to in the email?'],
#  ['<21139938.1075855669867.JavaMail.evans@thyme',
#   'What is being considered for prudency in the email?'],
#  ['<5886809.1075855669846.JavaMail.evans@thyme',
#   'Can you build something to look at historical prices from where we saved curves each night?'],
#  ['<5886809.1075855669846.JavaMail.evans@thyme',
#   'What is an example that pulls socal only?'],
#  ['<5886809.1075855669846.JavaMail.evans@thyme',
#   'What improvements could included for the curve selection?'],
#  ['<5886809.1075855669846.JavaMail.evans@thyme',
#   'What choices should be included for the curve selection?'],
#  ['<5886809.1075855669846.JavaMail.evans@thyme',
#   'What specific curves should be selectable according to the email?'],
#  ['<5886809.1075855669846.JavaMail.evans@thyme',
#   'Is there a mention of a drop down menu?'],
#  ['<20540702.1075855669674.JavaMail.evans@thyme',
#   'What must you obtain before authorizing overtime?'],
#  ['<20540702.1075855669674.JavaMail.evans@thyme',
#   'What are the daily timesheets for you and Wade required to be sent to?'],
#  ['<20540702.1075855669674.JavaMail.evans@thyme',
#   'When will paychecks be issued?'],
#  ['<20540702.1075855669674.JavaMail.evans@thyme',
#   'Where will the paychecks be issued from?'],
#  ['<20540702.1075855669674.JavaMail.evans@thyme',
#   'What has been attached to the email regarding the checkbook?'],
#  ['<20540702.1075855669674.JavaMail.evans@thyme',
#   'What are the yellow highlighted items in the spreadsheet related to?'],
#  ['<7671605.1075855669653.JavaMail.evans@thyme', 'Who will attend on Friday?'],
#  ['<7671605.1075855669653.JavaMail.evans@thyme',
#   'What has Keith Holst been managing?'],
#  ['<7671605.1075855669653.JavaMail.evans@thyme',
#   'On which desk has Keith Holst been managing transport?'],
#  ['<7671605.1075855669653.JavaMail.evans@thyme',
#   'What day is Phillip out of the office?'],
#  ['<14451083.1075855669437.JavaMail.evans@thyme',
#   'What did Paul Allen check into exercising options with?'],
#  ['<14451083.1075855669437.JavaMail.evans@thyme',
#   'What is Paul Allen starting to exercise now?'],
#  ['<14451083.1075855669437.JavaMail.evans@thyme',
#   'What is Paul Allen going to use the proceeds to buy?'],
#  ['<14451083.1075855669437.JavaMail.evans@thyme',
#   'What does Paul Allen think about selling JDSU?'],
#  ['<14451083.1075855669437.JavaMail.evans@thyme',
#   'What does Paul Allen want to look at as a play on rising oil and gas prices?'],
#  ['<14451083.1075855669437.JavaMail.evans@thyme',
#   'Who has an exclusive agreement with Enron?'],
#  ['<7570189.1075855669351.JavaMail.evans@thyme',
#   'What is the estimated gas price calculated in the email?'],
#  ['<7570189.1075855669351.JavaMail.evans@thyme',
#   'What is the current price of crude mentioned in the email?'],
#  ['<7570189.1075855669351.JavaMail.evans@thyme',
#   'How many shares are outstanding according to the email?'],
#  ['<7570189.1075855669351.JavaMail.evans@thyme',
#   'What is the calculated additional EPS mentioned in the email?'],
#  ['<7570189.1075855669351.JavaMail.evans@thyme',
#   'What companies does Phillip request reports on?'],
#  ['<7570189.1075855669351.JavaMail.evans@thyme',
#   'What valuation does Phillip estimate per share based on gas prices?'],
#  ['<4841855.1075855669329.JavaMail.evans@thyme',
#   'open the "utility" spreadsheet and try to complete the analysis'],
#  ['<4841855.1075855669329.JavaMail.evans@thyme',
#   'try to complete the analysis of whether it is better to be a small commercial or a medium commercial'],
#  ['<4841855.1075855669329.JavaMail.evans@thyme',
#   'get the usage for that meter for the last 12 months'],
#  ['<4841855.1075855669329.JavaMail.evans@thyme',
#   'if we have one year of data, we can tell which will be cheaper'],
#  ['<4841855.1075855669329.JavaMail.evans@thyme',
#   'use the rates described in the spreadsheet'],
#  ['<4841855.1075855669329.JavaMail.evans@thyme',
#   'this is a great chance for you to practice excel.'],
#  ['<20906618.1075855669287.JavaMail.evans@thyme',
#   'What is the time mentioned in the email?'],
#  ['<20906618.1075855669287.JavaMail.evans@thyme',
#   'What does Phillip want to make progress on?'],
#  ['<20906618.1075855669287.JavaMail.evans@thyme',
#   'What will Lucy probably need to do before attaching the file to an email?'],
#  ['<20906618.1075855669287.JavaMail.evans@thyme',
#   'What are the two files mentioned in the email?'],
#  ['<20906618.1075855669287.JavaMail.evans@thyme',
#   'What does Phillip refer to Lucy as in this email?'],
#  ['<11066301.1075855669245.JavaMail.evans@thyme',
#   'What did Phillip receive from Lucy?'],
#  ['<11066301.1075855669245.JavaMail.evans@thyme',
#   'What does Phillip suggest they do today?'],
#  ['<11066301.1075855669245.JavaMail.evans@thyme',
#   'Who is Phillip addressing in the email?'],
#  ['<11066301.1075855669245.JavaMail.evans@thyme',
#   "What is the purpose of Phillip's email to Lucy?"],
#  ['<11066301.1075855669245.JavaMail.evans@thyme',
#   'Who is working together with Phillip?'],
#  ['<11066301.1075855669245.JavaMail.evans@thyme',
#   'What attachment did Lucy send to Phillip?'],
#  ['<4546588.1075855669223.JavaMail.evans@thyme',
#   'What formula should be used in column e?'],
#  ['<4546588.1075855669223.JavaMail.evans@thyme',
#   'What should be the formula in column h?'],
#  ['<4546588.1075855669223.JavaMail.evans@thyme',
#   'What is causing column f to show #### signs?'],
#  ['<4546588.1075855669223.JavaMail.evans@thyme',
#   'What action should Lucy take to fix column f?'],
#  ['<4546588.1075855669223.JavaMail.evans@thyme',
#   'What does Phillip want to add to the right of the sheet after fixing the rent part?'],
#  ['<1875467.1075855669180.JavaMail.evans@thyme',
#   "What is Tori Kuykendall's new position according to the email?"],
#  ['<1875467.1075855669180.JavaMail.evans@thyme',
#   'What duties has Tori Kuykendall been performing since the beginning of the year?'],
#  ['<1875467.1075855669180.JavaMail.evans@thyme',
#   'Who is in a similar situation to Tori Kuykendall?'],
#  ['<1875467.1075855669180.JavaMail.evans@thyme',
#   'What action does Hunter want regarding Martin Cuilla?'],
#  ['<1875467.1075855669180.JavaMail.evans@thyme',
#   'What title does Paul Allen want to promote Tori Kuykendall to?'],
#  ['<1875467.1075855669180.JavaMail.evans@thyme',
#   'Are there any issues mentioned in the email regarding the promotions?'],
#  ['<4845981.1075855669114.JavaMail.evans@thyme',
#   'What was the anticipated socal/san juan spread on July 1?'],
#  ['<4845981.1075855669114.JavaMail.evans@thyme',
#   'What was the actual socal/san juan spread on July 1?'],
#  ['<4845981.1075855669114.JavaMail.evans@thyme',
#   'What was the perceived index on August 1?'],
#  ['<4845981.1075855669114.JavaMail.evans@thyme',
#   'What was the actual index on August 1?'],
#  ['<4845981.1075855669114.JavaMail.evans@thyme',
#   'What significant trend is noted about socal gas daily swaps?'],
#  ['<4845981.1075855669114.JavaMail.evans@thyme',
#   'What does Enron Online allow you to monitor?'],
#  ['<4789785.1075855669093.JavaMail.evans@thyme',
#   'What is the guest user id to access enrononline?'],
#  ['<4789785.1075855669093.JavaMail.evans@thyme',
#   'What is the guest password for temporary view only access to enrononline?'],
#  ['<4789785.1075855669093.JavaMail.evans@thyme',
#   'What is the phone number to call if there are problems logging in?'],
#  ['<4789785.1075855669093.JavaMail.evans@thyme',
#   'Where can the shockwave installer be found?'],
#  ['<4789785.1075855669093.JavaMail.evans@thyme',
#   'What is the title of the composite page set up for Mark?'],
#  ['<4789785.1075855669093.JavaMail.evans@thyme',
#   'What should you do after loading shockwave?'],
#  ['<14229093.1075855669027.JavaMail.evans@thyme',
#   'Were you able to log in to Enron Online?'],
#  ['<14229093.1075855669027.JavaMail.evans@thyme', 'Did you find SoCal today?'],
#  ['<14229093.1075855669027.JavaMail.evans@thyme',
#   'What list will Phillip follow up with?'],
#  ['<14229093.1075855669027.JavaMail.evans@thyme',
#   'What deals were done yesterday and today?'],
#  ['<27941245.1075855669006.JavaMail.evans@thyme',
#   'What month does the spreadsheet detail trades for?'],
#  ['<27941245.1075855669006.JavaMail.evans@thyme',
#   'What type of trades does the spreadsheet cover?'],
#  ['<27941245.1075855669006.JavaMail.evans@thyme',
#   'Did Phillip distinguish between buys and sells in the spreadsheet?'],
#  ['<27941245.1075855669006.JavaMail.evans@thyme',
#   'What format did Phillip use to communicate the trades?'],
#  ['<27941245.1075855669006.JavaMail.evans@thyme',
#   "What is the sender's name in the email?"],
#  ['<3652010.1075863687917.JavaMail.evans@thyme',
#   "Let's shoot for Tuesday at 11:45?"],
#  ['<31941463.1075855668856.JavaMail.evans@thyme',
#   'Can cooper give access to the new west power site?'],
#  ['<31941463.1075855668856.JavaMail.evans@thyme',
#   'Who is an analyst in our group?'],
#  ['<31941463.1075855668856.JavaMail.evans@thyme',
#   'What is the name of the person who needs access to the site?'],
#  ['<31941463.1075855668856.JavaMail.evans@thyme',
#   'What is the request made in the email?'],
#  ['<31941463.1075855668856.JavaMail.evans@thyme',
#   'What is the relationship between jay reitmeyer and Phillip Allen?'],
#  ['<7786081.1075855668835.JavaMail.evans@thyme',
#   'What does the 2000 California gas report show?'],
#  ['<7786081.1075855668835.JavaMail.evans@thyme',
#   'What is the number mentioned in the California gas report?'],
#  ['<7786081.1075855668835.JavaMail.evans@thyme',
#   'What might the 410 represent in the email?'],
#  ['<7786081.1075855668835.JavaMail.evans@thyme',
#   'What is being compared in the email?'],
#  ['<7786081.1075855668835.JavaMail.evans@thyme',
#   'Which two utilities are referenced in the email?'],
#  ['<6023619.1075855668680.JavaMail.evans@thyme',
#   'Who is the meeting scheduled with?'],
#  ['<6023619.1075855668680.JavaMail.evans@thyme',
#   'Is the meeting scheduled for tomorrow?'],
#  ['<6023619.1075855668680.JavaMail.evans@thyme',
#   'What is the name of the person for the meeting?'],
#  ['<29478027.1075855668659.JavaMail.evans@thyme',
#   'What is the price per duplex for the 22 units sold by Reagan Lehmann?'],
#  ['<29478027.1075855668659.JavaMail.evans@thyme',
#   'What is the bid amount mentioned in the email for the development opportunity?'],
#  ['<29478027.1075855668659.JavaMail.evans@thyme',
#   'What floor plan does Reagan mention some of the units are?'],
#  ['<4890198.1075855668548.JavaMail.evans@thyme',
#   'What is the price Phillip is prepared to pay for sagewood?'],
#  ['<4890198.1075855668548.JavaMail.evans@thyme',
#   'What business does Jeff appear to be involved in according to Phillip?'],
#  ['<4890198.1075855668548.JavaMail.evans@thyme',
#   'Did Phillip propose looking at developing a project from scratch?'],
#  ['<4890198.1075855668548.JavaMail.evans@thyme',
#   "What does Phillip express surprise about regarding Jeff's request?"],
#  ['<4890198.1075855668548.JavaMail.evans@thyme',
#   'Does Phillip indicate he is prepared to pay more than 2.7 for sagewood?'],
#  ['<9565310.1075855668527.JavaMail.evans@thyme',
#   'why is aeco basis so low on the list?'],
#  ['<9565310.1075855668527.JavaMail.evans@thyme',
#   'is nwpl mapped differently than aeco?'],
#  ['<9565310.1075855668527.JavaMail.evans@thyme',
#   'what about the correlation to nymex on aeco?'],
#  ['<21095120.1075855668506.JavaMail.evans@thyme',
#   'What was the difference in socal on 9/8 compared to 9/7?'],
#  ['<21095120.1075855668506.JavaMail.evans@thyme',
#   'How many shorts were added to san juan on 9/8?'],
#  ['<21095120.1075855668506.JavaMail.evans@thyme',
#   'How many longs were added to socal on 9/8?'],
#  ['<21095120.1075855668506.JavaMail.evans@thyme',
#   'How many san juan were bought before the adjustment?'],
#  ['<21095120.1075855668506.JavaMail.evans@thyme',
#   'How many socal were sold before the adjustment?'],
#  ['<21095120.1075855668506.JavaMail.evans@thyme',
#   'What is the net position for nwpl on 9/7?'],
#  ['<17442292.1075855668484.JavaMail.evans@thyme',
#   'What weekend is Phillip going to be in San Marcos?'],
#  ['<17442292.1075855668484.JavaMail.evans@thyme',
#   'What will Phillip be doing in San Marcos?'],
#  ['<17442292.1075855668484.JavaMail.evans@thyme',
#   'When will Phillip let Jeff know if he needs to see the inside?'],
#  ['<17442292.1075855668484.JavaMail.evans@thyme',
#   'What does Phillip want to find out about Chelsea Villa?'],
#  ['<17442292.1075855668484.JavaMail.evans@thyme',
#   'What does Phillip want to get a look at for the Burnet deal?'],
#  ['<17442292.1075855668484.JavaMail.evans@thyme',
#   'Who does Phillip mention that they need to make happy?'],
#  ['<16538156.1075855668397.JavaMail.evans@thyme',
#   'check 1406 walmart description and unit?'],
#  ['<16538156.1075855668397.JavaMail.evans@thyme',
#   'check 1410 crumps detail description and unit?'],
#  ['<16538156.1075855668397.JavaMail.evans@thyme',
#   'check 1411 lucy what is this?'],
#  ['<16538156.1075855668397.JavaMail.evans@thyme',
#   'check 1415 papes detail description and units?'],
#  ['<16538156.1075855668397.JavaMail.evans@thyme',
#   'checks 1416, 1417, and 1425 why overtime?'],
#  ['<16538156.1075855668397.JavaMail.evans@thyme',
#   "check 1428 ralph's what unit?"],
#  ['<26240402.1075855668375.JavaMail.evans@thyme',
#   'What is the check number that was mailed on August 28th?'],
#  ['<26240402.1075855668375.JavaMail.evans@thyme',
#   'What is the address to which the check was mailed?'],
#  ['<26240402.1075855668375.JavaMail.evans@thyme',
#   'What will Phillip do if the first check shows up?'],
#  ['<26240402.1075855668375.JavaMail.evans@thyme',
#   'What will Phillip send soon?'],
#  ['<26240402.1075855668375.JavaMail.evans@thyme',
#   'What is the concern that Phillip acknowledges regarding the site plan?'],
#  ['<26240402.1075855668375.JavaMail.evans@thyme',
#   'What will the second check be treated as if the first one shows up?'],
#  ['<2760663.1075855668353.JavaMail.evans@thyme',
#   'What does Paul Allen want to have as soon as possible?'],
#  ['<2760663.1075855668353.JavaMail.evans@thyme',
#   'Who did Paul Allen fax a copy of the file to?'],
#  ['<2760663.1075855668353.JavaMail.evans@thyme',
#   'What can Lucy do to the document he faxed?'],
#  ['<2760663.1075855668353.JavaMail.evans@thyme',
#   'What will Paul Allen do after Lucy fills in the correct amounts?'],
#  ['<32496474.1075855668332.JavaMail.evans@thyme',
#   'What site plan does Phillip need to see?'],
#  ['<32496474.1075855668332.JavaMail.evans@thyme',
#   'Who must give written approval before Phillip can sell the property?'],
#  ['<32496474.1075855668332.JavaMail.evans@thyme',
#   'What concerns does Brenda Key Stone have about the property?'],
#  ['<32496474.1075855668332.JavaMail.evans@thyme',
#   'What does Phillip want to review as soon as possible?'],
#  ['<8050013.1075855668290.JavaMail.evans@thyme',
#   'What is the bid price being offered by Phillip Allen?'],
#  ['<8050013.1075855668290.JavaMail.evans@thyme',
#   "How much higher is Phillip Allen's bid per square foot compared to Reagan's units under construction?"],
#  ['<8050013.1075855668290.JavaMail.evans@thyme',
#   'Which model does Phillip Allen believe is most similar to the units he is selling?'],
#  ['<8050013.1075855668290.JavaMail.evans@thyme',
#   'What did Deborah Yates inform George about the bid on the De Ville property?'],
#  ['<8050013.1075855668290.JavaMail.evans@thyme',
#   'What is the price per square foot that Phillip Allen is bidding compared to the units sold by Reagan?'],
#  ['<33241421.1075855668245.JavaMail.evans@thyme',
#   'What will be the ownership structure?'],
#  ['<33241421.1075855668245.JavaMail.evans@thyme',
#   'What happens to initial investment?'],
#  ['<33241421.1075855668245.JavaMail.evans@thyme',
#   'Is it used to purchase land for cash?'],
#  ['<33241421.1075855668245.JavaMail.evans@thyme',
#   'When is the 700,000 actually needed?'],
#  ['<33241421.1075855668245.JavaMail.evans@thyme',
#   'What relationship does Creekside Builders have to the project?'],
#  ['<33241421.1075855668245.JavaMail.evans@thyme',
#   'When will design be complete?'],
#  ['<27862517.1075855668223.JavaMail.evans@thyme',
#   "What is Denver's short Rockies position beyond 2002 created by?"],
#  ['<27862517.1075855668223.JavaMail.evans@thyme',
#   "What are the unhedged amounts for Denver's short Rockies position in 2003, 2004, and 2005?"],
#  ['<27862517.1075855668223.JavaMail.evans@thyme',
#   'When are they booking the Hubert deal?'],
#  ['<27862517.1075855668223.JavaMail.evans@thyme',
#   "How much is Denver's short Rockies position unhedged in 2003?"],
#  ['<27862517.1075855668223.JavaMail.evans@thyme',
#   "How much is Denver's short Rockies position unhedged in 2004 and 2005?"],
#  ['<27862517.1075855668223.JavaMail.evans@thyme',
#   'What are they doing to their books?'],
#  ['<20662978.1075855668202.JavaMail.evans@thyme',
#   'who should the guest password for gas daily be relayed to?'],
#  ['<20662978.1075855668202.JavaMail.evans@thyme',
#   'what is the location number for mike grigsby?'],
#  ['<20662978.1075855668202.JavaMail.evans@thyme',
#   'when will Phillip Allen be out of the office?'],
#  ['<20662978.1075855668202.JavaMail.evans@thyme',
#   'which company is mentioned in the email?'],
#  ['<20662978.1075855668202.JavaMail.evans@thyme',
#   'what password information does Phillip Allen request to be relayed?'],
#  ['<10929741.1075855668115.JavaMail.evans@thyme',
#   'what is the latest with pg&e?'],
#  ['<10929741.1075855668115.JavaMail.evans@thyme', 'who should chris call?'],
#  ['<10929741.1075855668115.JavaMail.evans@thyme',
#   'what has been discussed regarding eol?'],
#  ['<23408645.1075855667925.JavaMail.evans@thyme',
#   'What were the prices for San Juan gas on September 26 and 27?'],
#  ['<23408645.1075855667925.JavaMail.evans@thyme',
#   'Which days do the reported high physical prices refer to?'],
#  ['<23408645.1075855667925.JavaMail.evans@thyme',
#   'What financial trades correspond with the physical trades on those dates?'],
#  ['<23408645.1075855667925.JavaMail.evans@thyme',
#   'Which brokerage firms were involved in the reported trades?'],
#  ['<23408645.1075855667925.JavaMail.evans@thyme',
#   'What is the significance of the spread relationship between San Juan and other points?'],
#  ['<23408645.1075855667925.JavaMail.evans@thyme',
#   'What action does Enron desire regarding the index calculation?'],
#  ['<17435182.1075855667880.JavaMail.evans@thyme',
#   'What is the second check being used for?'],
#  ['<17435182.1075855667880.JavaMail.evans@thyme',
#   'When is the payment being made for?'],
#  ['<17435182.1075855667880.JavaMail.evans@thyme',
#   'Does Phillip want to fax the original deal to Brenda?'],
#  ['<31503589.1075855667838.JavaMail.evans@thyme',
#   'What month is the payment for?'],
#  ['<31503589.1075855667838.JavaMail.evans@thyme',
#   'What does Phillip Allen ask Brenda to use as the October payment?'],
#  ['<31503589.1075855667838.JavaMail.evans@thyme',
#   'What should Brenda do if she has already tossed the second check?'],
#  ['<31503589.1075855667838.JavaMail.evans@thyme',
#   'What is the content of the email regarding the checks?'],
#  ['<31503589.1075855667838.JavaMail.evans@thyme',
#   'What is the purpose of the email sent by Phillip Allen?'],
#  ['<14670081.1075855667751.JavaMail.evans@thyme', 'Is 35 million fine?'],
#  ['<14670081.1075855667751.JavaMail.evans@thyme', 'Who is Phillip?'],
#  ['<23634486.1075855667660.JavaMail.evans@thyme',
#   'What should Lucy click on after opening the rentrolls?'],
#  ['<23634486.1075855667660.JavaMail.evans@thyme',
#   'Where does Phillip instruct Lucy to save the rentroll files?'],
#  ['<23634486.1075855667660.JavaMail.evans@thyme',
#   'What is the first step in saving the rentroll files?'],
#  ['<23634486.1075855667660.JavaMail.evans@thyme',
#   'What is the last step Phillip mentions for saving the files?'],
#  ['<23634486.1075855667660.JavaMail.evans@thyme',
#   'What drive should Lucy click on to save the rentroll files?'],
#  ['<23634486.1075855667660.JavaMail.evans@thyme',
#   'What should Lucy do after clicking on the appropriate folder?'],
#  ['<5164240.1075855667637.JavaMail.evans@thyme',
#   'Who is the appropriate Enron entity for delivered gas behind San Diego?'],
#  ['<5164240.1075855667637.JavaMail.evans@thyme',
#   'Who did Phillip Allen forward the request to?'],
#  ['<5164240.1075855667637.JavaMail.evans@thyme',
#   "What is Zarin Imam's phone number?"],
#  ['<5164240.1075855667637.JavaMail.evans@thyme',
#   'What is the subject of the email from Phillip Allen?'],
#  ['<13486797.1075855667594.JavaMail.evans@thyme',
#   'What is the static IP address provided in the email?'],
#  ['<13486797.1075855667594.JavaMail.evans@thyme',
#   'What is the subnet mask listed for the IP address?'],
#  ['<13486797.1075855667594.JavaMail.evans@thyme',
#   'What is the gateway IP address mentioned in the email?'],
#  ['<13486797.1075855667594.JavaMail.evans@thyme',
#   'What is the DNS address included in the email?'],
#  ['<13486797.1075855667594.JavaMail.evans@thyme',
#   'What company code is mentioned in the email?'],
#  ['<13486797.1075855667594.JavaMail.evans@thyme',
#   'What is the rc number mentioned for the company?'],
#  ['<3651763.1075855667551.JavaMail.evans@thyme',
#   'What time between 10 am and 1 pm is good for looking at the plans?'],
#  ['<3651763.1075855667551.JavaMail.evans@thyme',
#   "What do you need me to do regarding the TV's?"],
#  ['<3651763.1075855667551.JavaMail.evans@thyme',
#   'Do we need plasma screens or would regular monitors be good at a fraction of the cost?'],
#  ['<14486500.1075863687839.JavaMail.evans@thyme',
#   'Can you send me a schedule of the salary and level of everyone in the scheduling group?'],
#  ['<14486500.1075863687839.JavaMail.evans@thyme',
#   'What are your thoughts on any changes that need to be made?'],
#  ['<14486500.1075863687839.JavaMail.evans@thyme',
#   'Who is an example of someone mentioned for potential changes?'],
#  ['<19402224.1075855667508.JavaMail.evans@thyme',
#   'What company is mentioned in the email?'],
#  ['<19402224.1075855667508.JavaMail.evans@thyme',
#   "What is the sender's email address?"],
#  ['<19402224.1075855667508.JavaMail.evans@thyme',
#   "What is the sender's phone number?"],
#  ['<19402224.1075855667508.JavaMail.evans@thyme',
#   'What action does the sender ask Jed to take?'],
#  ['<24771181.1075855667487.JavaMail.evans@thyme',
#   'Are you available at 5:30 ET today?'],
#  ['<24771181.1075855667487.JavaMail.evans@thyme',
#   'What is the date and time referenced in the email?'],
#  ['<1349081.1075855667466.JavaMail.evans@thyme',
#   'What did Patti Sullivan do to deserve a PBR award?'],
#  ['<1349081.1075855667466.JavaMail.evans@thyme',
#   'How long did Patti Sullivan hold together the scheduling group?'],
#  ['<1349081.1075855667466.JavaMail.evans@thyme',
#   'What time would Patti Sullivan typically arrive at the office?'],
#  ['<1349081.1075855667466.JavaMail.evans@thyme',
#   'Why was the information provided by Patti Sullivan critical this year?'],
#  ['<1349081.1075855667466.JavaMail.evans@thyme',
#   'Who did Patti Sullivan fill in for during their personal leave?'],
#  ['<1349081.1075855667466.JavaMail.evans@thyme',
#   'What specific event has made the information provided extremely critical this year?'],
#  ['<5195109.1075855667420.JavaMail.evans@thyme',
#   'Who did Phillip Allen speak to regarding the new electronic system?'],
#  ['<5195109.1075855667420.JavaMail.evans@thyme',
#   'What new electronic systems are being approved for the west desk?'],
#  ['<5195109.1075855667420.JavaMail.evans@thyme',
#   'What systems did Phillip mention besides Ice and Dynegy?'],
#  ['<5195109.1075855667420.JavaMail.evans@thyme',
#   "What is Phillip requesting from Andy's assistant?"],
#  ['<5195109.1075855667420.JavaMail.evans@thyme',
#   'What does Phillip want regarding IDs and passwords?'],
#  ['<5195109.1075855667420.JavaMail.evans@thyme',
#   'What is the first name of the individual Phillip is communicating with?'],
#  ['<12699764.1075855667399.JavaMail.evans@thyme',
#   'who should be assigned a user name?'],
#  ['<12699764.1075855667399.JavaMail.evans@thyme',
#   'what is the name of the person who needs a user name?'],
#  ['<12699764.1075855667399.JavaMail.evans@thyme',
#   'what is being requested in the email?'],
#  ['<12699764.1075855667399.JavaMail.evans@thyme',
#   'who is being addressed in the email?'],
#  ['<33165878.1075855667377.JavaMail.evans@thyme',
#   'Who held together the scheduling group for two months while Randy Gay was on personal leave?'],
#  ['<33165878.1075855667377.JavaMail.evans@thyme',
#   'How early did Patti Sullivan come to work to prepare operations reports?'],
#  ['<33165878.1075855667377.JavaMail.evans@thyme',
#   "What extra event occurred during Patti Sullivan's time managing the West desk?"],
#  ['<33165878.1075855667377.JavaMail.evans@thyme',
#   "What is Patti Sullivan's current job title?"],
#  ['<33165878.1075855667377.JavaMail.evans@thyme',
#   'What kind of recognition does Paul Allen suggest Patti Sullivan deserves?'],
#  ['<33165878.1075855667377.JavaMail.evans@thyme',
#   "What did Paul Allen request information about regarding Patti Sullivan's recognition?"],
#  ['<1367549.1075855667355.JavaMail.evans@thyme',
#   'What is the preferred rate of return that must be achieved before any profit sharing?'],
#  ['<1367549.1075855667355.JavaMail.evans@thyme',
#   'Who are the two principals involved in Creekside?'],
#  ['<1367549.1075855667355.JavaMail.evans@thyme',
#   'What changes does Phillip Allen suggest to better align the risk/reward profile?'],
#  ['<1367549.1075855667355.JavaMail.evans@thyme',
#   'What does Phillip Allen want regarding the investment structure?'],
#  ['<1367549.1075855667355.JavaMail.evans@thyme',
#   'How many years of projects completed does Phillip Allen request information about?'],
#  ['<1367549.1075855667355.JavaMail.evans@thyme',
#   'Who is one other investor mentioned in the email along with Keith?'],
#  ['<27253698.1075855667334.JavaMail.evans@thyme',
#   'Did you receive an email with a login and password yesterday?'],
#  ['<27253698.1075855667334.JavaMail.evans@thyme',
#   'Who did Phillip speak to regarding the guest ID?'],
#  ['<27253698.1075855667334.JavaMail.evans@thyme',
#   "What is Phillip's phone number?"],
#  ['<27253698.1075855667334.JavaMail.evans@thyme',
#   'What was requested for Dexter?'],
#  ['<27253698.1075855667334.JavaMail.evans@thyme',
#   'What type of support group did Phillip contact?'],
#  ['<20513208.1075855667313.JavaMail.evans@thyme',
#   'what is the heat rate given in the email?'],
#  ['<20513208.1075855667313.JavaMail.evans@thyme',
#   'what do the applied forward gas prices relate to?'],
#  ['<20513208.1075855667313.JavaMail.evans@thyme',
#   'what seems to be trading above the cap based on november 99 loads?'],
#  ['<20513208.1075855667313.JavaMail.evans@thyme',
# ...
#   'What does Phillip need to work with the engineer and architect to get moving?'],
#  ['<20430828.1075855696096.JavaMail.evans@thyme',
#   'What role did Jacques play in structuring the loan?'],
#  ['<20430828.1075855696096.JavaMail.evans@thyme',
#   "What is Phillip's intention regarding the partnership documents?"],
#  ['<20430828.1075855696096.JavaMail.evans@thyme',
#   'By when does Phillip hope to work out the extensions?'],
#  ['<14561005.1075855696007.JavaMail.evans@thyme',
#   'What was the response from Larry Lewter regarding the $15,000?'],
#  ['<14561005.1075855696007.JavaMail.evans@thyme',
#   'What issue is mentioned as no longer being a problem?'],
#  ['<14561005.1075855696007.JavaMail.evans@thyme',
#   'What is the name of the person whose response is included in the email?'],
#  ['<14561005.1075855696007.JavaMail.evans@thyme',
#   'What was the last issue to resolve according to Phillip?'],
#  ['<14561005.1075855696007.JavaMail.evans@thyme',
#   'What amount is referenced in the email regarding documentation?'],
#  ['<13910173.1075855695984.JavaMail.evans@thyme',
#   'What are the dates Phillip Allen will be out of the office?'],
#  ['<13910173.1075855695984.JavaMail.evans@thyme',
#   'Who is Phillip Allen planning to drop off a check for on Thursday?'],
#  ['<13910173.1075855695984.JavaMail.evans@thyme',
#   'What does Phillip Allen want Hugo Elizondo to file for?'],
#  ['<13910173.1075855695984.JavaMail.evans@thyme',
#   'What is Gordon Kohutek contracted to complete?'],
#  ['<13910173.1075855695984.JavaMail.evans@thyme',
#   'When does Gordon Kohutek say he will be done with his report?'],
#  ['<13910173.1075855695984.JavaMail.evans@thyme',
#   'What number can be used to reach Gordon Kohutek?'],
#  ['<12458711.1075855695961.JavaMail.evans@thyme',
#   'Who has been working with Claudia?'],
#  ['<12458711.1075855695961.JavaMail.evans@thyme',
#   'What will Phillip check this morning?'],
#  ['<12458711.1075855695961.JavaMail.evans@thyme',
#   "Who is checking Jacques' progress?"],
#  ['<17302921.1075855695897.JavaMail.evans@thyme',
#   'What is the total amount Phillip loaned to the project?'],
#  ['<17302921.1075855695897.JavaMail.evans@thyme',
#   'What assets are included in exhibit A?'],
#  ['<17302921.1075855695897.JavaMail.evans@thyme',
#   'What is the cash amount paid to the engineer and appraiser?'],
#  ['<17302921.1075855695897.JavaMail.evans@thyme',
#   'What is the reason for the bank declining the loan?'],
#  ['<17302921.1075855695897.JavaMail.evans@thyme',
#   'What is the status of the items listed as assets in exhibit A?'],
#  ['<17302921.1075855695897.JavaMail.evans@thyme',
#   'What obligations should include fees owed to the consultants?'],
#  ['<21196699.1075855695854.JavaMail.evans@thyme',
#   'Is Hugo planning to replatt using an administrative process?'],
#  ['<21196699.1075855695854.JavaMail.evans@thyme',
#   'How many parking spots does the builder in San Marcos believe the plan has?'],
#  ['<21196699.1075855695854.JavaMail.evans@thyme',
#   'How many parking spots are required by code?'],
#  ['<21196699.1075855695854.JavaMail.evans@thyme',
#   'What parking problem do the townhomes across the street have?'],
#  ['<21196699.1075855695854.JavaMail.evans@thyme',
#   'What are the garages being used as instead of parking?'],
#  ['<14900810.1075855695833.JavaMail.evans@thyme',
#   'What are the specific features of the house mentioned in the email?'],
#  ['<14900810.1075855695833.JavaMail.evans@thyme',
#   'What are the overall dimensions of the house?'],
#  ['<14900810.1075855695833.JavaMail.evans@thyme',
#   'What is the total square footage under roof as stated in the email?'],
#  ['<14900810.1075855695833.JavaMail.evans@thyme',
#   'How many square feet of livable space are there after deducting the garage?'],
#  ['<14900810.1075855695833.JavaMail.evans@thyme',
#   'What are the undecided items for the house?'],
#  ['<14900810.1075855695833.JavaMail.evans@thyme',
#   'What is the phone number to call for questions?'],
#  ['<31291337.1075855695811.JavaMail.evans@thyme',
#   "What is Mike's retention payment amount?"],
#  ['<31291337.1075855695811.JavaMail.evans@thyme',
#   'How long does Mike prefer to set strikes over?'],
#  ['<31291337.1075855695811.JavaMail.evans@thyme',
#   'Is Mike fine with signing a new contract?'],
#  ['<31291337.1075855695811.JavaMail.evans@thyme',
#   'When will Mike receive his retention payment?'],
#  ['<31291337.1075855695811.JavaMail.evans@thyme', 'Who sent this email?'],
#  ['<31291337.1075855695811.JavaMail.evans@thyme', "What is Mike's name?"],
#  ['<10083938.1075855695768.JavaMail.evans@thyme',
#   'What do the cost for on-site general requirements ($299,818) represent?'],
#  ['<10083938.1075855695768.JavaMail.evans@thyme', 'Why is profit only 4%?'],
#  ['<10083938.1075855695768.JavaMail.evans@thyme',
#   'What is the $617k of profit allowance?'],
#  ['<10083938.1075855695768.JavaMail.evans@thyme',
#   'Who receives the 2 points?'],
#  ['<10083938.1075855695768.JavaMail.evans@thyme',
#   'How much will be sunk costs if FHA declines us?'],
#  ['<10083938.1075855695768.JavaMail.evans@thyme',
#   'What is the status on the operating pro forma?'],
#  ['<5752490.1075855695704.JavaMail.evans@thyme',
#   'May I sign new consulting agreements with the engineer and architect?'],
#  ['<5752490.1075855695704.JavaMail.evans@thyme',
#   'How much was the only payment made by George and Larry to the architect?'],
#  ['<5752490.1075855695704.JavaMail.evans@thyme',
#   'What amounts have I written personal checks for to the architect and engineer?'],
#  ['<5752490.1075855695704.JavaMail.evans@thyme',
#   'Should I wait until the partnership has been conveyed to sign in the name of the partnership?'],
#  ['<5752490.1075855695704.JavaMail.evans@thyme',
#   'Do I want the agreements with these consultants to be with the partnership and not with me?'],
#  ['<5752490.1075855695704.JavaMail.evans@thyme',
#   'Do you think that the prior work needs to be listed as an asset of the partnership?'],
#  ['<33097150.1075855695661.JavaMail.evans@thyme',
#   'Is the framing lumber #2 yellow pine?'],
#  ['<33097150.1075855695661.JavaMail.evans@thyme',
#   'What type of floor joist would be used?'],
#  ['<33097150.1075855695661.JavaMail.evans@thyme',
#   'Are you planning for insulation between floors to dampen sound?'],
#  ['<33097150.1075855695661.JavaMail.evans@thyme',
#   'Did you bid for interior windows to have trim on 4 sides?'],
#  ['<33097150.1075855695661.JavaMail.evans@thyme',
#   'What type of construction contract would you use?'],
#  ['<33097150.1075855695661.JavaMail.evans@thyme',
#   'Are undermount sinks different than drop-ins?'],
#  ['<28301777.1075855695528.JavaMail.evans@thyme',
#   'What role would you play in obtaining financing?'],
#  ['<28301777.1075855695528.JavaMail.evans@thyme',
#   'What is the proposed total cost to boost the return to 31%?'],
#  ['<28301777.1075855695528.JavaMail.evans@thyme',
#   "What is the estimated cash flow for the project at the builder's fees provided?"],
#  ['<28301777.1075855695528.JavaMail.evans@thyme',
#   'What type of loans does Phillip inquire about in the email?'],
#  ['<28301777.1075855695528.JavaMail.evans@thyme',
#   'What are the percentages structured for onsite expenses, overhead, and profit?'],
#  ['<28301777.1075855695528.JavaMail.evans@thyme',
#   'What is the return rate at the current projected cash flow?'],
#  ['<9766679.1075855695415.JavaMail.evans@thyme',
#   'What assets are listed in the email?'],
#  ['<9766679.1075855695415.JavaMail.evans@thyme',
#   'Who is the appraisal conducted by?'],
#  ['<9766679.1075855695415.JavaMail.evans@thyme',
#   'What is the amount to reimburse for the appraisal?'],
#  ['<9766679.1075855695415.JavaMail.evans@thyme',
#   'What liabilities are mentioned in the email?'],
#  ['<9766679.1075855695415.JavaMail.evans@thyme',
#   'What is the outstanding invoice for Kipp Flores?'],
#  ['<9766679.1075855695415.JavaMail.evans@thyme',
#   'What engineering firm is mentioned in the preliminary engineering?'],
#  ['<563779.1075855695372.JavaMail.evans@thyme',
#   'Who did Phillip contact for the floor plan?'],
#  ['<563779.1075855695372.JavaMail.evans@thyme',
#   'What date will Phillip be in San Marcos?'],
#  ['<563779.1075855695372.JavaMail.evans@thyme',
#   'What is Phillip planning to engage Cary to do?'],
#  ['<563779.1075855695372.JavaMail.evans@thyme',
#   'What does Phillip want to work out while Cary is drawing the plans?'],
#  ['<563779.1075855695372.JavaMail.evans@thyme',
#   'Does Phillip want to visit homes that you have built?'],
#  ['<563779.1075855695372.JavaMail.evans@thyme',
#   'How many satisfied homeowners would Phillip like to speak to?'],
#  ['<32586184.1075855695351.JavaMail.evans@thyme',
#   'Who declined the employment agreement without a counter?'],
#  ['<32586184.1075855695351.JavaMail.evans@thyme',
#   'What is the proposed cash and equity offer that Keith would sign for?'],
#  ['<32586184.1075855695351.JavaMail.evans@thyme',
#   'What amount does Phillip believe Frank should receive as signing incentives?'],
#  ['<32586184.1075855695351.JavaMail.evans@thyme',
#   'Who are the individuals mentioned in the email regarding the employment agreement?'],
#  ['<32586184.1075855695351.JavaMail.evans@thyme',
#   "What is the equity portion of Keith's signing incentive?"],
#  ['<32586184.1075855695351.JavaMail.evans@thyme',
#   'What was the employment agreement outcome for Mike?'],
#  ['<16079397.1075855695329.JavaMail.evans@thyme',
#   'What is the total contract amount for Kipp Flores?'],
#  ['<16079397.1075855695329.JavaMail.evans@thyme',
#   'How much is outstanding for Kipp Flores?'],
#  ['<16079397.1075855695329.JavaMail.evans@thyme',
#   "What amount was paid for George & Larry's appraisal?"],
#  ['<16079397.1075855695329.JavaMail.evans@thyme',
#   'What is the total cash that Keith and Phillip will pay the sellers?'],
#  ['<16079397.1075855695329.JavaMail.evans@thyme',
#   'What is the engineering amount that Phillip mentioned?'],
#  ['<482102.1075855695308.JavaMail.evans@thyme',
#   'What date was Phillip Allen supposed to be in San Marcos?'],
#  ['<482102.1075855695308.JavaMail.evans@thyme',
#   'Who is going to draw the plans for the residence?'],
#  ['<482102.1075855695308.JavaMail.evans@thyme',
#   'Which project manager is Phillip Allen going to work with from San Antonio?'],
#  ['<482102.1075855695308.JavaMail.evans@thyme',
#   'Who is Kipp Flores in relation to the multifamily project?'],
#  ['<482102.1075855695308.JavaMail.evans@thyme',
#   'What made Phillip Allen consider another builder despite a competitive bid?'],
#  ['<482102.1075855695308.JavaMail.evans@thyme',
#   'What will Phillip Allen get back in touch with Reagan about?'],
#  ['<2829833.1075855695221.JavaMail.evans@thyme',
#   'What is the new closing date mentioned in the email?'],
#  ['<2829833.1075855695221.JavaMail.evans@thyme',
#   'What is Gary planning to put in #35?'],
#  ['<2829833.1075855695221.JavaMail.evans@thyme',
#   "What is Phillip's work number?"],
#  ['<2829833.1075855695221.JavaMail.evans@thyme',
#   'What day did the rentroll come from?'],
#  ['<2829833.1075855695221.JavaMail.evans@thyme',
#   'What is the deadline for Lucy to stay on until?'],
#  ['<2829833.1075855695221.JavaMail.evans@thyme',
#   'What was the original closing date before the delay?'],
#  ['<33143257.1075855695177.JavaMail.evans@thyme',
#   'What is the name of the architect being hired?'],
#  ['<33143257.1075855695177.JavaMail.evans@thyme',
#   'In which city is the architect located?'],
#  ['<33143257.1075855695177.JavaMail.evans@thyme',
#   'When does Phillip expect to send the detailed plan and spec list?'],
#  ['<33143257.1075855695177.JavaMail.evans@thyme',
#   'For what purpose will the architect help Phillip?'],
#  ['<33143257.1075855695177.JavaMail.evans@thyme',
#   'What type of plans is Phillip going to have drawn?'],
#  ['<33143257.1075855695177.JavaMail.evans@thyme',
#   "What was the purpose of Bruce's bid?"],
#  ['<16076840.1075855695133.JavaMail.evans@thyme',
#   'Was an environmental report prepared before the original purchase?'],
#  ['<16076840.1075855695133.JavaMail.evans@thyme',
#   "Shouldn't the environmental report be listed as an asset of the partnership?"],
#  ['<16076840.1075855695133.JavaMail.evans@thyme',
#   'Should your costs be recovered for the environmental report?'],
#  ['<17864070.1075855695090.JavaMail.evans@thyme',
#   'What is the status of Q3 compared to last year?'],
#  ['<17864070.1075855695090.JavaMail.evans@thyme',
#   'Did Phillip drop in the new generation in the spreadsheet?'],
#  ['<17864070.1075855695090.JavaMail.evans@thyme',
#   'What does Phillip want feedback on?'],
#  ['<17864070.1075855695090.JavaMail.evans@thyme',
#   'What is the context of the email regarding the plants?'],
#  ['<17864070.1075855695090.JavaMail.evans@thyme',
#   'What is the tone of the email regarding Q3 expectations?'],
#  ['<25179371.1075855695025.JavaMail.evans@thyme',
#   'What is the policy number?'],
#  ['<25179371.1075855695025.JavaMail.evans@thyme',
#   'Who is the contact person for the insurance company?'],
#  ['<25179371.1075855695025.JavaMail.evans@thyme',
#   'What time should the appraiser be scheduled for?'],
#  ['<25179371.1075855695025.JavaMail.evans@thyme',
#   'What is the address of the insurance company?'],
#  ['<25179371.1075855695025.JavaMail.evans@thyme',
#   'What is the name of the insurance company?'],
#  ['<25179371.1075855695025.JavaMail.evans@thyme',
#   'Who signed the actual policy?'],
#  ['<22047398.1075855694937.JavaMail.evans@thyme',
#   'How am I to send them the money for the silent second?'],
#  ['<22047398.1075855694937.JavaMail.evans@thyme',
#   'Will their bank make the funds available by Friday?'],
#  ['<22047398.1075855694937.JavaMail.evans@thyme',
#   'What are the wiring instructions?'],
#  ['<22047398.1075855694937.JavaMail.evans@thyme', 'Should I wire the money?'],
#  ['<22047398.1075855694937.JavaMail.evans@thyme',
#   'What is the deadline for sending the money?'],
#  ['<22047398.1075855694937.JavaMail.evans@thyme',
#   'What methods of sending the money are mentioned in the email?'],
#  ['<20930157.1075855694916.JavaMail.evans@thyme',
#   'Who should Chad call about the trading track program?'],
#  ['<20930157.1075855694916.JavaMail.evans@thyme',
#   "What should Chad's experience help with in the process?"],
#  ['<20930157.1075855694916.JavaMail.evans@thyme',
#   'What are the desks trying to use the trading track program for?'],
#  ['<20930157.1075855694916.JavaMail.evans@thyme',
#   'Is the risk rotation necessary according to the email?'],
#  ['<20930157.1075855694916.JavaMail.evans@thyme',
#   'Is Chad dying to do another rotation in risk?'],
#  ['<3749063.1075855694831.JavaMail.evans@thyme',
#   "What is Phillip Allen's first choice for the project?"],
#  ['<3749063.1075855694831.JavaMail.evans@thyme',
#   'When does Phillip Allen plan to build the house?'],
#  ['<3749063.1075855694831.JavaMail.evans@thyme',
#   'What does Phillip Allen want to incorporate into the home design?'],
#  ['<3749063.1075855694831.JavaMail.evans@thyme',
#   'What does Phillip Allen want Johnnie to email him when complete?'],
#  ['<3749063.1075855694831.JavaMail.evans@thyme',
#   'What budgetary aspect does Phillip Allen mention regarding the panel system?'],
#  ['<3749063.1075855694831.JavaMail.evans@thyme',
#   'What does Phillip Allen express optimism about after the meeting on Friday?'],
#  ['<4703459.1075855694767.JavaMail.evans@thyme',
#   'What should he send to Karen Buckley in HR?'],
#  ['<4703459.1075855694767.JavaMail.evans@thyme',
#   'When is the new round of trading track interviews?'],
#  ['<4703459.1075855694767.JavaMail.evans@thyme',
#   'Who is the HR contact mentioned in the email?'],
#  ['<30350978.1075855694788.JavaMail.evans@thyme',
#   "Who should Bryan Hull's resume be forwarded to?"],
#  ['<30350978.1075855694788.JavaMail.evans@thyme',
#   'Which program is Bryan Hull best suited for?'],
#  ['<30350978.1075855694788.JavaMail.evans@thyme',
#   "What is Bryan Hull's full name?"],
#  ['<30350978.1075855694788.JavaMail.evans@thyme',
#   "What is Phillip Allen's opinion about Bryan Hull's resume?"],
#  ['<4999405.1075855694746.JavaMail.evans@thyme',
#   'Who should receive the resume?'],
#  ['<4999405.1075855694746.JavaMail.evans@thyme',
#   'When will there be a full round of interviews for the trading track?'],
#  ...]
